# %% [markdown]
# <a href="https://colab.research.google.com/github/mtsvi-moraes/mtsvi-moraes/blob/main/Python_pra_An%C3%A1lise_de_Dados_Cargas_de_Dados%2C_armazenagem_e_formatos_de_aquivo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Carga de dados, armazenagem e formatos de arquivo**

# %% [markdown]
# ## **Lendo e salvando arquivos csv:**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([['um', 'a', 1, 2], ['um', 'b', 3, 4], ['um','c', 5, 6], ['um','d', 7, 8], ['dois','a', 9, 10], ['dois','b', 11, 12], ['dois', 'c', 13, 14],['dois', 'd', 15, 16]], 
                 columns = ['chave1', 'chave2', 'valor1', 'valor2'])
df.to_csv('/content/drive/MyDrive/Data Science/Python para Analise de Dados/df.csv', index=False, header=True)

# %% [markdown]
# **Escolhendo a coluna na ordem que eu determinar:**

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Data Science/Python para Analise de Dados/df.csv', sep=',', index_col= ['chave1', 'chave2'])
df2
# Out:
#                valor1  valor2
# chave1 chave2
# um     a            1       2
#        b            3       4
#        c            5       6
#        d            7       8
# dois   a            9      10
#        b           11      12
#        c           13      14
#        d           15      16

# %% [markdown]
# **Pulando linhas:**

# %%
df3 = pd.read_csv('/content/drive/MyDrive/Data Science/Python para Analise de Dados/df.csv', sep=',', skiprows= [0, 6])
df3
# Out:
#      um  a   1   2
# 0    um  b   3   4
# 1    um  c   5   6
# 2    um  d   7   8
# 3  dois  a   9  10
# 4  dois  c  13  14
# 5  dois  d  15  16

# %% [markdown]
# **Definindo quantas linhas o arquivo vai aparecer:**

# %%
df4 = pd.read_csv('/content/drive/MyDrive/Data Science/Python para Analise de Dados/df.csv', sep=',', nrows=3)
df4
# Out:
#   chave1 chave2  valor1  valor2
# 0     um      a       1       2
# 1     um      b       3       4
# 2     um      c       5       6

# %% [markdown]
# **Obs: Também é possível colocar diferentes separadores. Nesse caso stdout dá um print na expressão**

# %%
import sys

# %%
df4.to_csv(sys.stdout, sep='|')
# Out:
# |chave1|chave2|valor1|valor2
# 0|um|a|1|2
# 1|um|b|3|4
# 2|um|c|5|6

# %% [markdown]
# **Não apenas df's podem ser convertidos pra outro formato, mas Series também:**

# %%
datas = pd.date_range('08/08/1997', periods=10)
calendario = pd.Series(np.arange(1, 11), index=datas)
calendario
# Out:
# 1997-08-08     1
# 1997-08-09     2
# 1997-08-10     3
# 1997-08-11     4
# 1997-08-12     5
# 1997-08-13     6
# 1997-08-14     7
# 1997-08-15     8
# 1997-08-16     9
# 1997-08-17    10
# Freq: D, dtype: int64

# %% [markdown]
# **Salvando series em diversos formatos:**

# %%
calendario.to_csv('/content/drive/MyDrive/Data Science/Python para Analise de Dados/calendario.csv', index=False)
calendario.to_json('/content/drive/MyDrive/Data Science/Python para Analise de Dados/calendario.json')
calendario.to_excel('/content/drive/MyDrive/Data Science/Python para Analise de Dados/calendario.xlsx')

# %%
import csv
random = open('/content/drive/MyDrive/Data Science/Python para Analise de Dados/Files/random.csv', )
arquivo = csv.reader(random, delimiter='|', quotechar='"', lineterminator='\n', quoting = csv.QUOTE_MINIMAL)

# %%
for x in arquivo:
  print(x)
# Out:
# ['\ufeff"feathers"', 'yourself', 'correct', 'queen', 'extra', 'girl', 'condition', 'enjoy', 'instead', 'nearest']
# ['teach', 'famous', 'success', 'inch', 'getting', 'three', 'flew', 'finger', 'nice', 'still']
# ['when', 'movie', 'heavy', 'view', 'stay', 'mean', 'white', 'raw', 'calm', 'tea']
# ['jungle', 'none', 'box', 'relationship', 'volume', 'given', 'effect', 'labor', 'lips', 'asleep']
# ['second', 'want', 'look', 'slope', 'branch', 'fly', 'scale', 'worker', 'blank', 'lips']
# ['ordinary', 'dot', 'copper', 'pine', 'let', 'shown', 'yellow', 'football', 'children', 'suppose']
# ['official', 'cross', 'sale', 'teeth', 'without', 'central', 'familiar', 'draw', 'fix', 'danger']
# ['waste', 'primitive', 'solve', 'noun', 'college', 'breath', 'came', 'including', 'health', 'victory']
# ['master', 'memory', 'action', 'death', 'week', 'laugh', 'get', 'no', 'library', 'away']
# ['say', 'swimming', 'hour', 'ground', 'cut', 'again', 'purpose', 'given', 'shelter', 'short']
# ['temperature', 'mirror', 'day', 'love', 'own', 'cloud', 'village', 'won', 'substance', 'immediately']

# %%
with open('/content/drive/MyDrive/Data Science/Python para Analise de Dados/Files/random.csv') as random:
  lines = list(csv.reader(random))
  header, values = lines[0], lines[1:]

data_dict = {h: v for h, v in zip(header, zip(*values))}
data_dict
# Out:
# {'\ufeff"feathers"|"yourself"|"correct"|"queen"|"extra"|"girl"|"condition"|"enjoy"|"instead"|"nearest"': ('teach|"famous"|"success"|"inch"|"getting"|"three"|"flew"|"finger"|"nice"|"still"',
#   'when|"movie"|"heavy"|"view"|"stay"|"mean"|"white"|"raw"|"calm"|"tea"',
#   'jungle|"none"|"box"|"relationship"|"volume"|"given"|"effect"|"labor"|"lips"|"asleep"',
#   'second|"want"|"look"|"slope"|"branch"|"fly"|"scale"|"worker"|"blank"|"lips"',
#   'ordinary|"dot"|"copper"|"pine"|"let"|"shown"|"yellow"|"football"|"children"|"suppose"',
#   'official|"cross"|"sale"|"teeth"|"without"|"central"|"familiar"|"draw"|"fix"|"danger"',
#   'waste|"primitive"|"solve"|"noun"|"college"|"breath"|"came"|"including"|"health"|"victory"',
#   'master|"memory"|"action"|"death"|"week"|"laugh"|"get"|"no"|"library"|"away"',
#   'say|"swimming"|"hour"|"ground"|"cut"|"again"|"purpose"|"given"|"shelter"|"short"',
#   'temperature|"mirror"|"day"|"love"|"own"|"cloud"|"village"|"won"|"substance"|"immediately"')}

# %%
class my_dialect(csv.Dialect):
  lineterminator = '\n'
  delimiter = ';'
  quotechar = '"'
  quoting = csv.QUOTE_MINIMAL
reader = csv.reader(arquivo, dialect=my_dialect)

# %%
# !cat examples/ex7.csv
# Out:
# cat: examples/ex7.csv: No such file or directory

# %%
random1 = pd.read_table('/content/drive/MyDrive/Data Science/Python para Analise de Dados/Files/random.csv', sep='|')
random1
# Out:
#       feathers   yourself  correct  ...      enjoy    instead      nearest
# 0        teach     famous  success  ...     finger       nice        still
# 1         when      movie    heavy  ...        raw       calm          tea
# 2       jungle       none      box  ...      labor       lips       asleep
# 3       second       want     look  ...     worker      blank         lips
# 4     ordinary        dot   copper  ...   football   children      suppose
# 5     official      cross     sale  ...       draw        fix       danger
# 6        waste  primitive    solve  ...  including     health      victory
# 7       master     memory   action  ...         no    library         away
# 8          say   swimming     hour  ...      given    shelter        short
# 9  temperature     mirror      day  ...        won  substance  immediately
#
# [10 rows x 10 columns]

# %% [markdown]
# ## **Trabalhando com *JSONS*:**

# %%
JSON = pd.read_json('/content/drive/MyDrive/Data Science/Python para Analise de Dados/generated.json')
JSON.head()
# Out:
#                         _id  ...  favoriteFruit
# 0  60d4f8cb838bfdfbe65ac8c3  ...         banana
# 1  60d4f8cbc76c4553f90ef163  ...          apple
# 2  60d4f8cbb173544b52bd29dc  ...     strawberry
# 3  60d4f8cb29592322b9b3283f  ...         banana
# 4  60d4f8cb2ff7425a609a853a  ...         banana
#
# [5 rows x 22 columns]

# %% [markdown]
# ### **Convertendo Jsons para python:**

# %%
obj = """
{"nome": "Eduardo",
"lugares_viveu": ["Brasil", "Japao", "Ucrania"],
"pet": null,
"siblings": [{"Nome": "Icaro", "Idade": 30, "pets": ["Zeus", "Zuleika"]},
{"Nome": "Katarina", "Idade": 38,
"pets": ["Chico", "Bolhudo", "Jonnatan"]}]
}
"""

# %%
import json
json_python = json.loads(obj)
json_python
# Out:
# {'lugares_viveu': ['Brasil', 'Japao', 'Ucrania'],
#  'nome': 'Eduardo',
#  'pet': None,
#  'siblings': [{'Idade': 30, 'Nome': 'Icaro', 'pets': ['Zeus', 'Zuleika']},
#   {'Idade': 38, 'Nome': 'Katarina', 'pets': ['Chico', 'Bolhudo', 'Jonnatan']}]}

# %% [markdown]
# **Filtrando items e construindo DF de JSONS:**

# %%
irmaos = pd.DataFrame(json_python['siblings'], columns=['Nome', 'Idade'])
irmaos
# Out:
#        Nome  Idade
# 0     Icaro     30
# 1  Katarina     38

# %% [markdown]
# **Convertendo objeto Python para JSON:**

# %%
python_json = json.dumps(json_python)
python_json
# Out:
# '{"nome": "Eduardo", "lugares_viveu": ["Brasil", "Japao", "Ucrania"], "pet": null, "siblings": [{"Nome": "Icaro", "Idade": 30, "pets": ["Zeus", "Zuleika"]}, {"Nome": "Katarina", "Idade": 38, "pets": ["Chico", "Bolhudo", "Jonnatan"]}]}'

# %% [markdown]
# ## **Trabalhando com dados HTML/XML:**

# %% [markdown]
# **Obs: Quando você faz scraping, ele retorna uma lista de DF**

# %%
html = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')
np.shape(html)
# Out:
# (1, 563, 7)

# %%
 type(html)
# Out:
# list

# %%
len(html)
# Out:
# 1

# %%
falhas = html[0]
np.shape(falhas)
# Out:
# (563, 7)

# %%
falhas
# Out:
#                          Bank NameBank  ... FundFund
# 0                    Almena State Bank  ...    10538
# 1           First City Bank of Florida  ...    10537
# 2                 The First State Bank  ...    10536
# 3                   Ericson State Bank  ...    10535
# 4     City National Bank of New Jersey  ...    10534
# ..                                 ...  ...      ...
# 558                 Superior Bank, FSB  ...     6004
# 559                Malta National Bank  ...     4648
# 560    First Alliance Bank & Trust Co.  ...     4647
# 561  National State Bank of Metropolis  ...     4646
# 562                   Bank of Honolulu  ...     4645
#
# [563 rows x 7 columns]

# %% [markdown]
# ### **Tratando os dados HTML:**

# %%
falhas.head()
# Out:
#                       Bank NameBank  ... FundFund
# 0                 Almena State Bank  ...    10538
# 1        First City Bank of Florida  ...    10537
# 2              The First State Bank  ...    10536
# 3                Ericson State Bank  ...    10535
# 4  City National Bank of New Jersey  ...    10534
#
# [5 rows x 7 columns]

# %%
falencia = pd.to_datetime(falhas['Closing DateClosing'])
falencia.dt.year.value_counts()
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2017      8
# 2015      8
# 2016      5
# 2004      4
# 2001      4
# 2020      4
# 2019      4
# 2003      3
# 2007      3
# 2000      2
# Name: Closing DateClosing, dtype: int64

# %% [markdown]
# ### **Trabalhando com dados XML:**

# %%
from lxml import objectify

# %%
path = '/content/drive/MyDrive/Data Science/Python para Analise de Dados/Files/arquivo3.xml'
arquivo1 = objectify.parse(open(path))
root = arquivo1.getroot()

data = []
skip_fields = ['PARENT_SEQ', 'INDICATOR_SEQ', 'DESIRED_CHANGE', 'DECIMAL_PLACES', 'YEAR']

for elt in root:
  el_data = {}
  for child in elt.getchildren():
    if child.tag in skip_fields:
      continue
    el_data[child.tag] = child.pyval
data.append(el_data)

# %%
perf = pd.DataFrame(data)
perf.head()
# Out:
#             AGENCY_NAME          INDICATOR_NAME  ... MONTHLY_TARGET  MONTHLY_ACTUAL
# 0  Metro-North Railroad  Escalator Availability  ...           97.0
#
# [1 rows x 12 columns]

# %%
from io import StringIO
tag = '<a href="http://www.google.com">Google</a>'
root = objectify.parse(StringIO(tag)).getroot()

root.get('href')
# Out:
# 'http://www.google.com'

# %%
root.text
# Out:
# 'Google'

# %% [markdown]
# ##**Trabalhando com binários:**

# %% [markdown]
# Uma das formas mais simples de armazenar dados (também
# conhecida como serialização) de modo eficiente em formato binário é usando a serialização embutida pickle de Python. Serialização e Desserialização são mecanismos usados em muitos ambientes quando você precisa converter qualquer objeto  para algo que você pode colocar “fora” do seu aplicativo.  Esta conversão pode ser em ambos os sentidos, e é muito conveniente se você precisar salvar ou transferir dados (Ex: Criar um arquivo “exportação” / “backup” em um projeto, etc).

# %%
picles = calendario.to_pickle('/content/drive/MyDrive/Data Science/Python para Analise de Dados/calendario_pickle')

# %%
pd.read_pickle('/content/drive/MyDrive/Data Science/Python para Analise de Dados/calendario_pickle')
# Out:
# 1997-08-08     1
# 1997-08-09     2
# 1997-08-10     3
# 1997-08-11     4
# 1997-08-12     5
# 1997-08-13     6
# 1997-08-14     7
# 1997-08-15     8
# 1997-08-16     9
# 1997-08-17    10
# Freq: D, dtype: int64

# %% [markdown]
# ### **Arquivos Feather: Extremamente rápidos para DF's**

# %%
feather = df.to_feather('/content/drive/MyDrive/Data Science/Python para Analise de Dados/df.feather')
feather

# %%
pd.read_feather('/content/drive/MyDrive/Data Science/Python para Analise de Dados/df.feather')
# Out:
#   chave1 chave2  valor1  valor2
# 0     um      a       1       2
# 1     um      b       3       4
# 2     um      c       5       6
# 3     um      d       7       8
# 4   dois      a       9      10
# 5   dois      b      11      12
# 6   dois      c      13      14
# 7   dois      d      15      16

# %% [markdown]
# ***Bcolz***: Um conteiner que lê arquivos com muitas linhas e 'zipa' ele:

# %% [markdown]
# ### **Arquivos DF5**: Utilizado para **arquivos locais enormes** em formato **comprimido**

# %%
df5 = pd.DataFrame({'a': np.arange(10000)})
df5
# Out:
#          a
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
# ...    ...
# 9995  9995
# 9996  9996
# 9997  9997
# 9998  9998
# 9999  9999
#
# [10000 rows x 1 columns]

# %%
path = pd.HDFStore('/content/drive/MyDrive/Data Science/Python para Analise de Dados/mydata.h5')
path['obj1'] = df5
path['obj1_col'] = df5['a']
path
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: /content/drive/MyDrive/Data Science/Python para Analise de Dados/mydata.h5

# %%
path['obj1']
# Out:
#          a
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
# ...    ...
# 9995  9995
# 9996  9996
# 9997  9997
# 9998  9998
# 9999  9999
#
# [10000 rows x 1 columns]

# %% [markdown]
# **Criando colunas e fazendo queries:**

# %% [markdown]
# Obs: HDFStore aceita dois esquemas de armazenagem: 'fixed' e 'table'. Table é mais lento, porém aceita queries

# %%
path.put('obj2', df5, format='table')

# %% [markdown]
# Obs: path.put('obj2', df5, format='table') == path['obj2'] = df5

# %%
path.select('obj2', where=['index >= 30 and index <=50'])
# Out:
#      a
# 30  30
# 31  31
# 32  32
# 33  33
# 34  34
# 35  35
# 36  36
# 37  37
# 38  38
# 39  39
# 40  40
# 41  41
# 42  42
# 43  43
# 44  44
# 45  45
# 46  46
# 47  47
# 48  48
# 49  49
# 50  50

# %% [markdown]
# ## **Trabalhando com arquivos excel:**

# %% [markdown]
# ### **Abrindo arquivos em Excel:**

# %% [markdown]
# **Obs: Ambos os métodos fazem a mesma coisa, no entanto, ExcelFile é mais rápido, principalmente quando se tratar de vários arquivos**

# %%
xlsx = pd.ExcelFile('/content/drive/MyDrive/Data Science/Python para Analise de Dados/calendario.xlsx')
xlsx.parse()
# Out:
#   Unnamed: 0   0
# 0 1997-08-08   1
# 1 1997-08-09   2
# 2 1997-08-10   3
# 3 1997-08-11   4
# 4 1997-08-12   5
# 5 1997-08-13   6
# 6 1997-08-14   7
# 7 1997-08-15   8
# 8 1997-08-16   9
# 9 1997-08-17  10

# %%
xlsx2 = pd.read_excel('/content/drive/MyDrive/Data Science/Python para Analise de Dados/calendario.xlsx')
xlsx2
# Out:
#   Unnamed: 0   0
# 0 1997-08-08   1
# 1 1997-08-09   2
# 2 1997-08-10   3
# 3 1997-08-11   4
# 4 1997-08-12   5
# 5 1997-08-13   6
# 6 1997-08-14   7
# 7 1997-08-15   8
# 8 1997-08-16   9
# 9 1997-08-17  10

# %% [markdown]
# ### **Salvando arquivos excel:**

# %%
writer = pd.ExcelWriter('/content/drive/MyDrive/Data Science/Python para Analise de Dados/exemplo2.xlsx')
df4.to_excel(writer)
writer.save()
df4
# Out:
#   chave1 chave2  valor1  valor2
# 0     um      a       1       2
# 1     um      b       3       4
# 2     um      c       5       6

# %%
xlsx2.to_excel('/content/drive/MyDrive/Data Science/Python para Analise de Dados/exemplo3.xlsx')

# %% [markdown]
# ## **Trabalhando com dados de APIs web:**

# %%
import requests

# %%
 url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
 resp = requests.get(url)
 resp
# Out:
# <Response [200]>

# %%
dados = resp.json()
dados
# Out:
# [{'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'MEMBER',
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n\r\nThere are a bunch of issues that boil down to this weird behavior.  I need to track down the full list (@attack68 do you have such a list handy?)',
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42351/comments',
#   'created_at': '2021-07-02T23:42:06Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42351/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42351',
#   'id': 936119377,
#   'labels': [],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42351/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjgyOTI2MDE4',
#   'number': 42351,
#   'performed_via_github_app': None,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/42351.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42351',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42351.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42351'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'DEPR: ignoring missing labels when indexing on MultiIndex level',
#   'updated_at': '2021-07-02T23:42:06Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42351',
#   'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/jbrockmendel',
#    'id': 8078968,
#    'login': 'jbrockmendel',
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/jbrockmendel'}},
#  {'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'MEMBER',
#   'body': '- [x] closes #42287\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [x] whatsnew entry\r\n',
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42350/comments',
#   'created_at': '2021-07-02T21:59:52Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42350/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42350',
#   'id': 936086587,
#   'labels': [{'color': 'e10c02',
#     'default': False,
#     'description': None,
#     'id': 76811,
#     'name': 'Bug',
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug'},
#    {'color': 'd4c5f9',
#     'default': False,
#     'description': 'rolling, ewma, expanding',
#     'id': 1045950827,
#     'name': 'Window',
#     'node_id': 'MDU6TGFiZWwxMDQ1OTUwODI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Window'},
#    {'color': '5319e7',
#     'default': False,
#     'description': 'Specific to numba-accelerated operations.',
#     'id': 2138993554,
#     'name': 'numba',
#     'node_id': 'MDU6TGFiZWwyMTM4OTkzNTU0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/numba'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42350/labels{/name}',
#   'locked': False,
#   'milestone': {'closed_at': None,
#    'closed_issues': 69,
#    'created_at': '2021-06-09T18:28:42Z',
#    'creator': {'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'gravatar_id': '',
#     'html_url': 'https://github.com/jreback',
#     'id': 953992,
#     'login': 'jreback',
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'site_admin': False,
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'type': 'User',
#     'url': 'https://api.github.com/users/jreback'},
#    'description': '',
#    'due_on': '2021-12-31T08:00:00Z',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/86',
#    'id': 6840253,
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86/labels',
#    'node_id': 'MDk6TWlsZXN0b25lNjg0MDI1Mw==',
#    'number': 86,
#    'open_issues': 43,
#    'state': 'open',
#    'title': '1.4',
#    'updated_at': '2021-07-02T21:59:59Z',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86'},
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjgyODk3NzUy',
#   'number': 42350,
#   'performed_via_github_app': None,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/42350.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42350',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42350.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42350'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': "BUG: Don't cache args during rolling/expanding.apply with numba engine",
#   'updated_at': '2021-07-02T22:01:02Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42350',
#   'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/mroeschke',
#    'id': 10647082,
#    'login': 'mroeschke',
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/mroeschke'}},
#  {'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'MEMBER',
#   'body': 'The \'level\' argument in MultiIndex methods can be ambiguous in at least 2 ways.\r\n\r\n1) If an index\'s level names are `[1, 0]`, then `level=0` may refer to either level depending on whether it is a position or a label #21677.\r\n\r\n2) If an index level names are `["foo", "bar", ("foo, "bar")]`, then `level=("foo", "bar")` may refer to either the first two levels, or the last level #21120\r\n\r\nOne option to address the first one is adding keywords to specify e.g. level_num or level_name #10461\r\n\r\nThe new idea I\'d like to discuss is having a `pd.Label` class to treat something ambiguous as a label.  So in the first case, passing `level=pd.Label(0)` would indicate that you want the second level.  In the second case, `level=pd.Label(("foo", "bar"))` would indicate that this should be interpreted as a single label and not a sequence of labels.\r\n\r\nFollowing an appropriate deprecation cycle, the default would be to interpret ambiguous cases as positional/sequence unless pd.Label is explicitly used.\r\n\r\npd.Label has a couple of other potential uses\r\n\r\nA) If `frame.index` (or `series.index.levels[0]`) contains tuples, then `df.loc[a, b]` may either be selecting a single key `(a, b)` from the index, or may be selecting `a` from the index and `b` from the columns.  `df.loc[pd.Label((a, b))` would disambiguate\r\n\r\nB) in `__getitem__/__setitem__` pd.Label could indicate to use .loc and not fallback to .iloc (not that useful since the user could just use .loc directly)',
#   'closed_at': None,
#   'comments': 1,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42349/comments',
#   'created_at': '2021-07-02T18:51:15Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42349/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42349',
#   'id': 936001052,
#   'labels': [{'color': 'AD7FA8',
#     'default': False,
#     'description': None,
#     'id': 35818298,
#     'name': 'API Design',
#     'node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42349/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'node_id': 'MDU6SXNzdWU5MzYwMDEwNTI=',
#   'number': 42349,
#   'performed_via_github_app': None,
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'API: pd.Label to disambiguate e.g. MultiIndex level, or tuple as sequence vs label',
#   'updated_at': '2021-07-02T19:11:53Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42349',
#   'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/jbrockmendel',
#    'id': 8078968,
#    'login': 'jbrockmendel',
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/jbrockmendel'}},
#  {'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'CONTRIBUTOR',
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n\r\n#### Problem description\r\n\r\nThe list of assets published on Pypi for pandas 1.3.0 does not contain assets for Python 3.8 and Python 3.9. See the list [here](https://pypi.org/project/pandas/1.3.0/#files)\r\n\r\nFor comparison, in Pandas 1.2.5, the list of published assets is [here](https://pypi.org/project/pandas/1.2.5/#files).\r\n\r\n#### Expected Output\r\n\r\nI expected the same list of assets as the one of Pandas 1.2.5 for Pandas 1.3.0.',
#   'closed_at': None,
#   'comments': 3,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42347/comments',
#   'created_at': '2021-07-02T16:26:12Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42347/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42347',
#   'id': 935912349,
#   'labels': [{'color': 'DDDDDD',
#     'default': False,
#     'description': 'Administrative tasks related to the pandas project',
#     'id': 32933285,
#     'name': 'Admin',
#     'node_id': 'MDU6TGFiZWwzMjkzMzI4NQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Admin'},
#    {'color': '006b75',
#     'default': False,
#     'description': None,
#     'id': 131473665,
#     'name': 'Release',
#     'node_id': 'MDU6TGFiZWwxMzE0NzM2NjU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Release'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42347/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'node_id': 'MDU6SXNzdWU5MzU5MTIzNDk=',
#   'number': 42347,
#   'performed_via_github_app': None,
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'RLS: Missing assets in release 1.3.0',
#   'updated_at': '2021-07-02T17:43:03Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42347',
#   'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/12542576?v=4',
#    'events_url': 'https://api.github.com/users/benoit9126/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/benoit9126/followers',
#    'following_url': 'https://api.github.com/users/benoit9126/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/benoit9126/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/benoit9126',
#    'id': 12542576,
#    'login': 'benoit9126',
#    'node_id': 'MDQ6VXNlcjEyNTQyNTc2',
#    'organizations_url': 'https://api.github.com/users/benoit9126/orgs',
#    'received_events_url': 'https://api.github.com/users/benoit9126/received_events',
#    'repos_url': 'https://api.github.com/users/benoit9126/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/benoit9126/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/benoit9126/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/benoit9126'}},
#  {'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'NONE',
#   'body': "- [x] closes #6878\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n\r\nProbably the hardest part of this PR is choosing a good name for the new argument. As mentioned in #6878 the `name` keyword is already used in `Series.reset_index`, although to rename the data column. It could be argued that using `name` also in this PR would not cause confusion, since it's hard to assume one can rename a column's name in `DataFrame.reset_index` (which column would it be?). \r\n\r\nAnyway, I've opted for `names`. I've also thought of `rename` but that sounds like asking for a boolean. `new_name` is an option too, although a bit ugly.",
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42346/comments',
#   'created_at': '2021-07-02T15:42:15Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42346/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42346',
#   'id': 935882908,
#   'labels': [],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42346/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjgyNzI0MTUx',
#   'number': 42346,
#   'performed_via_github_app': None,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/42346.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42346',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42346.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42346'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'Rename index when using DataFrame.reset_index',
#   'updated_at': '2021-07-02T15:42:49Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42346',
#   'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/44147817?v=4',
#    'events_url': 'https://api.github.com/users/gcaria/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/gcaria/followers',
#    'following_url': 'https://api.github.com/users/gcaria/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gcaria/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/gcaria',
#    'id': 44147817,
#    'login': 'gcaria',
#    'node_id': 'MDQ6VXNlcjQ0MTQ3ODE3',
#    'organizations_url': 'https://api.github.com/users/gcaria/orgs',
#    'received_events_url': 'https://api.github.com/users/gcaria/received_events',
#    'repos_url': 'https://api.github.com/users/gcaria/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/gcaria/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gcaria/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/gcaria'}},
#  {'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'CONTRIBUTOR',
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n**Note**: Please read [this guide](https://matthewrocklin.com/blog/work/2018/02/28/minimal-bug-reports) detailing how to provide the necessary information for us to reproduce your bug.\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\nI created a notebook here to illustrate the issue\r\n\r\nhttps://colab.research.google.com/drive/1por9_BTeLYvZxNzLOBv_jIsFh44mnz4N?usp=sharing\r\n\r\nMain error message:\r\n\r\n```\r\n/usr/local/lib/python3.7/dist-packages/pandas/_libs/internals.pyx in pandas._libs.internals.BlockManager.__cinit__()\r\n\r\nTypeError: __cinit__() takes at least 2 positional arguments (0 given)\r\n```\r\n\r\n#### Problem description\r\n\r\nDataframes saved with pandas 1.2.5 and "pickle" are no longer loadable with pandas 1.3.0\r\n\r\nRelated to #42343\r\n\r\n#### Expected Output\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : f00ed8f47020034e752baf0250483053340971b0\r\npython           : 3.7.10.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.4.104+\r\nVersion          : #1 SMP Sat Jun 5 09:50:34 PDT 2021\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.3.0\r\nnumpy            : 1.19.5\r\npytz             : 2018.9\r\ndateutil         : 2.8.1\r\npip              : 19.3.1\r\nsetuptools       : 57.0.0\r\nCython           : 0.29.23\r\npytest           : 3.6.4\r\nhypothesis       : None\r\nsphinx           : 1.8.5\r\nblosc            : None\r\nfeather          : 0.4.1\r\nxlsxwriter       : None\r\nlxml.etree       : 4.2.6\r\nhtml5lib         : 1.0.1\r\npymysql          : None\r\npsycopg2         : 2.7.6.1 (dt dec pq3 ext lo64)\r\njinja2           : 2.11.3\r\nIPython          : 5.5.0\r\npandas_datareader: 0.9.0\r\nbs4              : 4.6.3\r\nbottleneck       : 1.3.2\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.2.2\r\nnumexpr          : 2.7.3\r\nodfpy            : None\r\nopenpyxl         : 2.5.9\r\npandas_gbq       : 0.13.3\r\npyarrow          : 3.0.0\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.4.1\r\nsqlalchemy       : 1.4.18\r\ntables           : 3.4.4\r\ntabulate         : 0.8.9\r\nxarray           : 0.18.2\r\nxlrd             : 1.1.0\r\nxlwt             : 1.3.0\r\nnumba            : 0.51.2\r\n\r\n\r\n</details>\r\n',
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42345/comments',
#   'created_at': '2021-07-02T15:33:25Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42345/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42345',
#   'id': 935876620,
#   'labels': [{'color': 'e10c02',
#     'default': False,
#     'description': None,
#     'id': 76811,
#     'name': 'Bug',
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug'},
#    {'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member',
#     'id': 1954720290,
#     'name': 'Needs Triage',
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42345/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'node_id': 'MDU6SXNzdWU5MzU4NzY2MjA=',
#   'number': 42345,
#   'performed_via_github_app': None,
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'BUG: regression for 1.3.0: saving a dataframe with the "pickle" package using pandas 1.2.5 would not open with "pickle" again with pandas 1.3.0',
#   'updated_at': '2021-07-02T15:37:42Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42345',
#   'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/8392324?v=4',
#    'events_url': 'https://api.github.com/users/shadiakiki1986/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/shadiakiki1986/followers',
#    'following_url': 'https://api.github.com/users/shadiakiki1986/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shadiakiki1986/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/shadiakiki1986',
#    'id': 8392324,
#    'login': 'shadiakiki1986',
#    'node_id': 'MDQ6VXNlcjgzOTIzMjQ=',
#    'organizations_url': 'https://api.github.com/users/shadiakiki1986/orgs',
#    'received_events_url': 'https://api.github.com/users/shadiakiki1986/received_events',
#    'repos_url': 'https://api.github.com/users/shadiakiki1986/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/shadiakiki1986/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shadiakiki1986/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/shadiakiki1986'}},
#  {'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'MEMBER',
#   'body': "Tracking issue for the 1.3.1 release.\r\n\r\nhttps://github.com/pandas-dev/pandas/milestone/87\r\n\r\nCurrently scheduled for July 25, 2021 (date flexible on severity of regressions)\r\n\r\nList of open regressions: https://github.com/pandas-dev/pandas/issues?q=is%3Aopen+is%3Aissue+label%3ARegression\r\n\r\nsignificant performance regressions between 1.2.5 and 1.3.0\r\n\r\n```\r\n       before           after         ratio\r\n     [7c48ff44]       [f00ed8f4]\r\n     <v1.2.5^0>       <v1.3.0^0>\r\n+     2.43±0.03ms         28.4±1ms    11.66  indexing.InsertColumns.time_assign_list_like_with_setitem\r\n+     5.79±0.08ms       29.9±0.4ms     5.17  frame_methods.MaskBool.time_frame_mask_bools\r\n+      88.7±0.9μs          453±5μs     5.11  inference.ToTimedelta.time_convert_int\r\n+        82.6±2ms          386±1ms     4.67  frame_ctor.FromDicts.time_nested_dict_int64\r\n+        363±10μs      1.26±0.01ms     3.48  stat_ops.FrameOps.time_op('prod', 'int', 1)\r\n+         537±7μs      1.84±0.01ms     3.43  stat_ops.FrameOps.time_op('mean', 'int', 1)\r\n+         341±3μs      1.09±0.01ms     3.21  stat_ops.FrameOps.time_op('sum', 'int', 1)\r\n+        643±10μs      1.95±0.01ms     3.03  rolling.EWMMethods.time_ewm('Series', 1000, 'float', 'mean')\r\n+         626±6μs      1.88±0.03ms     3.00  rolling.EWMMethods.time_ewm('Series', 10, 'float', 'mean')\r\n+         678±9μs      2.00±0.04ms     2.95  rolling.EWMMethods.time_ewm('Series', 10, 'int', 'mean')\r\n+        696±10μs      2.01±0.01ms     2.89  rolling.EWMMethods.time_ewm('Series', 1000, 'int', 'mean')\r\n+         592±9μs      1.68±0.01ms     2.84  stat_ops.FrameOps.time_op('mean', 'int', 0)\r\n+        758±10μs      2.11±0.02ms     2.79  rolling.EWMMethods.time_ewm('DataFrame', 10, 'float', 'mean')\r\n+     1.34±0.01ms       3.73±0.1ms     2.78  stat_ops.FrameOps.time_op('std', 'int', 0)\r\n+        804±10μs      2.21±0.03ms     2.75  rolling.EWMMethods.time_ewm('DataFrame', 10, 'int', 'mean')\r\n+         479±4μs      1.32±0.04ms     2.75  stat_ops.FrameOps.time_op('sum', 'int', 0)\r\n+         213±4ns          583±8ns     2.74  tslibs.timestamp.TimestampProperties.time_freqstr(None, 'B')\r\n+         218±2ns          592±4ns     2.72  tslibs.timestamp.TimestampProperties.time_freqstr(<DstTzInfo 'US/Pacific' LMT-1 day, 16:07:00 STD>, 'B')\r\n+     1.32±0.03ms      3.58±0.04ms     2.70  stat_ops.FrameOps.time_op('var', 'int', 0)\r\n+         221±2ns          595±9ns     2.69  tslibs.timestamp.TimestampProperties.time_freqstr(tzlocal(), 'B')\r\n+         216±2ns          582±6ns     2.69  tslibs.timestamp.TimestampProperties.time_freqstr(datetime.timezone(datetime.timedelta(seconds=3600)), 'B')\r\n+         212±4ns         567±10ns     2.68  tslibs.timestamp.TimestampProperties.time_freqstr(tzfile('/usr/share/zoneinfo/Asia/Tokyo'), 'B')\r\n```\r\n\r\ncc @pandas-dev/pandas-core @pandas-dev/pandas-triage ",
#   'closed_at': None,
#   'comments': 2,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42343/comments',
#   'created_at': '2021-07-02T13:45:44Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42343/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42343',
#   'id': 935786335,
#   'labels': [{'color': '006b75',
#     'default': False,
#     'description': None,
#     'id': 131473665,
#     'name': 'Release',
#     'node_id': 'MDU6TGFiZWwxMzE0NzM2NjU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Release'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42343/labels{/name}',
#   'locked': False,
#   'milestone': {'closed_at': None,
#    'closed_issues': 2,
#    'created_at': '2021-06-25T09:56:22Z',
#    'creator': {'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'gravatar_id': '',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'id': 13159005,
#     'login': 'simonjayhawkins',
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'site_admin': False,
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'type': 'User',
#     'url': 'https://api.github.com/users/simonjayhawkins'},
#    'description': 'on-merge: backport to 1.3.x',
#    'due_on': '2021-07-25T07:00:00Z',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/87',
#    'id': 6888188,
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/87/labels',
#    'node_id': 'MDk6TWlsZXN0b25lNjg4ODE4OA==',
#    'number': 87,
#    'open_issues': 16,
#    'state': 'open',
#    'title': '1.3.1',
#    'updated_at': '2021-07-02T17:24:30Z',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/87'},
#   'node_id': 'MDU6SXNzdWU5MzU3ODYzMzU=',
#   'number': 42343,
#   'performed_via_github_app': None,
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'RLS: 1.3.1',
#   'updated_at': '2021-07-02T14:43:50Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42343',
#   'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#    'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#    'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/simonjayhawkins',
#    'id': 13159005,
#    'login': 'simonjayhawkins',
#    'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#    'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#    'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#    'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/simonjayhawkins'}},
#  {'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'CONTRIBUTOR',
#   'body': 'follows up an oversigh from #40628.\r\n`False` was deprecated as an input so the example should be updated.',
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42342/comments',
#   'created_at': '2021-07-02T10:35:15Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42342/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42342',
#   'id': 935644126,
#   'labels': [{'color': '3465A4',
#     'default': False,
#     'description': None,
#     'id': 134699,
#     'name': 'Docs',
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42342/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjgyNTIyMjkz',
#   'number': 42342,
#   'performed_via_github_app': None,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/42342.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42342',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42342.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42342'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'DOC: fix docs after deprecation of args',
#   'updated_at': '2021-07-02T22:13:44Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42342',
#   'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/24256554?v=4',
#    'events_url': 'https://api.github.com/users/attack68/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/attack68/followers',
#    'following_url': 'https://api.github.com/users/attack68/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/attack68/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/attack68',
#    'id': 24256554,
#    'login': 'attack68',
#    'node_id': 'MDQ6VXNlcjI0MjU2NTU0',
#    'organizations_url': 'https://api.github.com/users/attack68/orgs',
#    'received_events_url': 'https://api.github.com/users/attack68/received_events',
#    'repos_url': 'https://api.github.com/users/attack68/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/attack68/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/attack68/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/attack68'}},
#  {'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'NONE',
#   'body': 'Currently, the [user guide for groupby](https://pandas.pydata.org/docs/dev/user_guide/groupby.html#dataframe-column-selection-in-groupby) shows the following code, but it is unclear where the "C" and "D" columns come from.\r\n\r\n![image](https://user-images.githubusercontent.com/7686641/124226033-48346700-dabd-11eb-90a1-be764c93f934.png)\r\n\r\nIn the rendered documentation, the preceding definition of `df` does not have "C" and "D" columns.\r\n\r\n```python\r\nIn [50]: arrays = [\r\n   ....:     ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],\r\n   ....:     ["one", "two", "one", "two", "one", "two", "one", "two"],\r\n   ....: ]\r\n   ....: \r\n\r\nIn [51]: index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])\r\n\r\nIn [52]: df = pd.DataFrame({"A": [1, 1, 1, 1, 2, 2, 3, 3], "B": np.arange(8)}, index=index)\r\n\r\nIn [53]: df\r\nOut[53]: \r\n              A  B\r\nfirst second      \r\nbar   one     1  0\r\n      two     1  1\r\nbaz   one     1  2\r\n      two     1  3\r\nfoo   one     2  4\r\n      two     2  5\r\nqux   one     3  6\r\n      two     3  7\r\n```\r\n\r\nInstead, the code under the heading "DataFrame column selection in GroupBy" is referring to a completely different dataframe which is in the RST file but is suppressed in the rendered documentation.\r\n\r\nThis pull request un-suppresses that relevant dataframe so that readers can see where the "C" and "D" columns come from.',
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42340/comments',
#   'created_at': '2021-07-02T05:43:53Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42340/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42340',
#   'id': 935436732,
#   'labels': [],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42340/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjgyMzUyMDIx',
#   'number': 42340,
#   'performed_via_github_app': None,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/42340.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42340',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42340.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42340'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'DOC: Unsuppress relevant dataframe in split-apply-combine guide',
#   'updated_at': '2021-07-02T05:44:04Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42340',
#   'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/7686641?v=4',
#    'events_url': 'https://api.github.com/users/chrisyeh96/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/chrisyeh96/followers',
#    'following_url': 'https://api.github.com/users/chrisyeh96/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/chrisyeh96/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/chrisyeh96',
#    'id': 7686641,
#    'login': 'chrisyeh96',
#    'node_id': 'MDQ6VXNlcjc2ODY2NDE=',
#    'organizations_url': 'https://api.github.com/users/chrisyeh96/orgs',
#    'received_events_url': 'https://api.github.com/users/chrisyeh96/received_events',
#    'repos_url': 'https://api.github.com/users/chrisyeh96/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/chrisyeh96/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/chrisyeh96/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/chrisyeh96'}},
#  {'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'MEMBER',
#   'body': '- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [x] whatsnew entry\r\n',
#   'closed_at': None,
#   'comments': 2,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42339/comments',
#   'created_at': '2021-07-02T04:56:30Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42339/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42339',
#   'id': 935413848,
#   'labels': [{'color': '4E9A06',
#     'default': False,
#     'description': None,
#     'id': 76812,
#     'name': 'Enhancement',
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement'},
#    {'color': 'd4c5f9',
#     'default': False,
#     'description': 'rolling, ewma, expanding',
#     'id': 1045950827,
#     'name': 'Window',
#     'node_id': 'MDU6TGFiZWwxMDQ1OTUwODI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Window'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42339/labels{/name}',
#   'locked': False,
#   'milestone': {'closed_at': None,
#    'closed_issues': 69,
#    'created_at': '2021-06-09T18:28:42Z',
#    'creator': {'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'gravatar_id': '',
#     'html_url': 'https://github.com/jreback',
#     'id': 953992,
#     'login': 'jreback',
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'site_admin': False,
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'type': 'User',
#     'url': 'https://api.github.com/users/jreback'},
#    'description': '',
#    'due_on': '2021-12-31T08:00:00Z',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/86',
#    'id': 6840253,
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86/labels',
#    'node_id': 'MDk6TWlsZXN0b25lNjg0MDI1Mw==',
#    'number': 86,
#    'open_issues': 43,
#    'state': 'open',
#    'title': '1.4',
#    'updated_at': '2021-07-02T21:59:59Z',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86'},
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjgyMzMzNzU0',
#   'number': 42339,
#   'performed_via_github_app': None,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/42339.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42339',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42339.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42339'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': "ENH: Add `method='table'` for EWM.mean",
#   'updated_at': '2021-07-02T22:29:21Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42339',
#   'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/mroeschke',
#    'id': 10647082,
#    'login': 'mroeschke',
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/mroeschke'}},
#  {'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'MEMBER',
#   'body': '- [ ] closes #42248\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'closed_at': None,
#   'comments': 2,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42338/comments',
#   'created_at': '2021-07-01T23:06:36Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42338/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42338',
#   'id': 935277145,
#   'labels': [{'color': 'd4c5f9',
#     'default': False,
#     'description': 'Series/DataFrame/Index/pd.array Constructors',
#     'id': 1465286368,
#     'name': 'Constructors',
#     'node_id': 'MDU6TGFiZWwxNDY1Mjg2MzY4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Constructors'},
#    {'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance',
#     'id': 8935311,
#     'name': 'Performance',
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42338/labels{/name}',
#   'locked': False,
#   'milestone': {'closed_at': None,
#    'closed_issues': 2,
#    'created_at': '2021-06-25T09:56:22Z',
#    'creator': {'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'gravatar_id': '',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'id': 13159005,
#     'login': 'simonjayhawkins',
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'site_admin': False,
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'type': 'User',
#     'url': 'https://api.github.com/users/simonjayhawkins'},
#    'description': 'on-merge: backport to 1.3.x',
#    'due_on': '2021-07-25T07:00:00Z',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/87',
#    'id': 6888188,
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/87/labels',
#    'node_id': 'MDk6TWlsZXN0b25lNjg4ODE4OA==',
#    'number': 87,
#    'open_issues': 16,
#    'state': 'open',
#    'title': '1.3.1',
#    'updated_at': '2021-07-02T17:24:30Z',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/87'},
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjgyMjIxNTIy',
#   'number': 42338,
#   'performed_via_github_app': None,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/42338.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42338',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42338.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42338'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'PERF/REGR: revert #41785',
#   'updated_at': '2021-07-02T16:29:14Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42338',
#   'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/jbrockmendel',
#    'id': 8078968,
#    'login': 'jbrockmendel',
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/jbrockmendel'}},
#  {'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'MEMBER',
#   'body': '- [x] closes #42055\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [x] whatsnew entry\r\n',
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42335/comments',
#   'created_at': '2021-07-01T17:06:31Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42335/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42335',
#   'id': 935047979,
#   'labels': [{'color': 'e10c02',
#     'default': False,
#     'description': None,
#     'id': 76811,
#     'name': 'Bug',
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug'},
#    {'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves',
#     'id': 2822098,
#     'name': 'Indexing',
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing'},
#    {'color': '207de5',
#     'default': False,
#     'description': None,
#     'id': 71268330,
#     'name': 'MultiIndex',
#     'node_id': 'MDU6TGFiZWw3MTI2ODMzMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/MultiIndex'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42335/labels{/name}',
#   'locked': False,
#   'milestone': {'closed_at': None,
#    'closed_issues': 69,
#    'created_at': '2021-06-09T18:28:42Z',
#    'creator': {'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'gravatar_id': '',
#     'html_url': 'https://github.com/jreback',
#     'id': 953992,
#     'login': 'jreback',
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'site_admin': False,
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
# ...
#    'followers_url': 'https://api.github.com/users/fangchenli/followers',
#    'following_url': 'https://api.github.com/users/fangchenli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fangchenli/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/fangchenli',
#    'id': 7614606,
#    'login': 'fangchenli',
#    'node_id': 'MDQ6VXNlcjc2MTQ2MDY=',
#    'organizations_url': 'https://api.github.com/users/fangchenli/orgs',
#    'received_events_url': 'https://api.github.com/users/fangchenli/received_events',
#    'repos_url': 'https://api.github.com/users/fangchenli/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/fangchenli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fangchenli/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/fangchenli'}},
#  {'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'CONTRIBUTOR',
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\nIIUC for pandas extension arrays, for each location where `_mask` is `True`, the value of `_data` should be irrelevant. However this is not the case for `__array_ufunc__`:\r\n\r\n```python\r\nIn [1]: import pandas as pd\r\n   ...: import numpy as np\r\n   ...: \r\n   ...: arr = pd.array([True, False, pd.NA], dtype="boolean")\r\n   ...: arr\r\nOut[1]: \r\n<BooleanArray>\r\n[True, False, <NA>]\r\nLength: 3, dtype: boolean\r\n\r\nIn [2]: y = np.ones(3, bool)\r\n   ...: out = np.ones(3, bool)\r\n   ...: \r\n   ...: np.logical_and(arr, y, out=out)\r\n   ...: out\r\nOut[2]: array([ True, False, False])\r\n\r\nIn [3]: arr._data[2] = True  # This does not change arr since arr._mask[2] = True\r\n   ...: \r\n   ...: np.logical_and(arr, y, out=out)\r\n   ...: out\r\nOut[3]: array([ True, False,  True])\r\n```\r\n\r\nRelevant code:\r\nhttps://github.com/pandas-dev/pandas/blob/17ecb56c219d8d01399faffcffa8f059ecf6fd45/pandas/core/arrays/boolean.py#L366-L390\r\n\r\nHere we are calling \r\n```python\r\nresult = np.logical_and(arr._data, y, out=out)\r\nreturn BooleanArray(result, arr._mask)\r\n```\r\nwhich adjusts `out` in-place, ignoring the mask and depending on `arr._data[2]`.\r\n\r\nThis issue shows how this might be an issue:\r\nhttps://github.com/numpy/numpy/issues/19374\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\nIn [4]: pd.show_versions()\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2cb96529396d93b46abab7bbc73a208e708c642e\r\npython           : 3.9.2.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.4.0-74-generic\r\nVersion          : #83-Ubuntu SMP Sat May 8 02:35:39 UTC 2021\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.2.4\r\nnumpy            : 1.21.0\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : 21.1.1\r\nsetuptools       : 49.6.0.post20210108\r\nCython           : None\r\npytest           : 6.2.3\r\nhypothesis       : None\r\nsphinx           : 3.5.4\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.3\r\nIPython          : 7.23.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : 2021.04.0\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.4.2\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 4.0.1\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.6.3\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : 0.8.9\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n\r\n\r\n</details>\r\n',
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42303/comments',
#   'created_at': '2021-06-29T14:17:16Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42303/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42303',
#   'id': 932738401,
#   'labels': [{'color': 'e10c02',
#     'default': False,
#     'description': None,
#     'id': 76811,
#     'name': 'Bug',
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug'},
#    {'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member',
#     'id': 1954720290,
#     'name': 'Needs Triage',
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42303/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'node_id': 'MDU6SXNzdWU5MzI3Mzg0MDE=',
#   'number': 42303,
#   'performed_via_github_app': None,
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'BUG: `__array_ufunc__` with for functions with side-effects depends on `_data`',
#   'updated_at': '2021-06-29T14:17:16Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42303',
#   'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/61679398?v=4',
#    'events_url': 'https://api.github.com/users/mlondschien/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/mlondschien/followers',
#    'following_url': 'https://api.github.com/users/mlondschien/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mlondschien/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/mlondschien',
#    'id': 61679398,
#    'login': 'mlondschien',
#    'node_id': 'MDQ6VXNlcjYxNjc5Mzk4',
#    'organizations_url': 'https://api.github.com/users/mlondschien/orgs',
#    'received_events_url': 'https://api.github.com/users/mlondschien/received_events',
#    'repos_url': 'https://api.github.com/users/mlondschien/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/mlondschien/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mlondschien/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/mlondschien'}},
#  {'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'CONTRIBUTOR',
#   'body': 'This refactors `Styler.bar` to allow more flexible arguments to align bars, and an additional keyword `props` akin to other builtin methods that allow some customisation, demonstrated in the new user guide (image below)\r\n\r\n- [x] closes #26070\r\n- [x] tests added / passed\r\n- [x] whats new\r\n\r\n**All previous tests pass with minor formatting alterations.**\r\n\r\nAs a follow-on I should improve the original testing for this function - it is sporadic and unstructured.\r\n\r\n![Screen Shot 2021-06-29 at 14 53 56](https://user-images.githubusercontent.com/24256554/123800804-f2f42c00-d8e9-11eb-970a-31468d7a29fa.png)\r\n',
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42301/comments',
#   'created_at': '2021-06-29T13:14:18Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42301/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42301',
#   'id': 932653321,
#   'labels': [{'color': '4E9A06',
#     'default': False,
#     'description': None,
#     'id': 76812,
#     'name': 'Enhancement',
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement'},
#    {'color': '006b75',
#     'default': False,
#     'description': 'conditional formatting using DataFrame.style',
#     'id': 1728592794,
#     'name': 'Styler',
#     'node_id': 'MDU6TGFiZWwxNzI4NTkyNzk0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Styler'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42301/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Njc5OTcyNDIx',
#   'number': 42301,
#   'performed_via_github_app': None,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/42301.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42301',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42301.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42301'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'ENH: `Styler.bar` extended to allow centering about the mean, value or callable',
#   'updated_at': '2021-06-30T18:49:56Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42301',
#   'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/24256554?v=4',
#    'events_url': 'https://api.github.com/users/attack68/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/attack68/followers',
#    'following_url': 'https://api.github.com/users/attack68/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/attack68/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/attack68',
#    'id': 24256554,
#    'login': 'attack68',
#    'node_id': 'MDQ6VXNlcjI0MjU2NTU0',
#    'organizations_url': 'https://api.github.com/users/attack68/orgs',
#    'received_events_url': 'https://api.github.com/users/attack68/received_events',
#    'repos_url': 'https://api.github.com/users/attack68/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/attack68/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/attack68/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/attack68'}},
#  {'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'NONE',
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\n# Float column casted to int\r\nd1 = pd.DataFrame({"a": [1.0, 2.0], \'b\': [3, np.nan]})\r\nprint(\'\\nd1:\')\r\nprint(d1)\r\nprint(\'\\nd1.dtypes:\')\r\nprint(d1.dtypes)\r\nprint(\'\\nd1.where(pd.notnull(d1), None):\')\r\nprint(d1.where(pd.notnull(d1), None))\r\n\r\nprint()\r\n\r\n# Float column not casted to int\r\nd2 = pd.DataFrame({"a": [1.0, 2.0], \'b\': [3, 4]})\r\nprint(\'\\nd2:\')\r\nprint(d2)\r\nprint(\'\\nd2.dtypes:\')\r\nprint(d2.dtypes)\r\nprint(\'\\nd2.where(pd.notnull(d2), None):\')\r\nprint(d2.where(pd.notnull(d2), None))\r\n\r\n```\r\n![E50BED38-3414-4414-AF7A-87A39546CF2B](https://user-images.githubusercontent.com/20555592/123768444-9df3ee00-d8c8-11eb-8601-35f4eaa45993.png)\r\n\r\n\r\n\r\n#### Problem description\r\n\r\nIn both previous examples, the column `a` is identical (a float column containing 1.0 and 2.0), but the outcome of `df.where(pd.notnull(df), None)` differs. \r\n\r\n#### Expected Output\r\n\r\nFor a given column, I would expect the outcome of `df.where(pd.notnull(df), None)` to be consistent, regardless of the other columns of the dataframe.\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2cb96529396d93b46abab7bbc73a208e708c642e\r\npython           : 3.9.5.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 19.6.0\r\nVersion          : Darwin Kernel Version 19.6.0: Tue Jan 12 22:13:05 PST 2021; root:xnu-6153.141.16~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : en_US.UTF-8\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.2.4\r\nnumpy            : 1.20.3\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : 21.1.2\r\nsetuptools       : 49.6.0\r\nCython           : 0.29.23\r\npytest           : 6.2.3\r\nhypothesis       : None\r\nsphinx           : 3.5.4\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : 1.4.3\r\nlxml.etree       : 4.6.3\r\nhtml5lib         : None\r\npymysql          : 1.0.2\r\npsycopg2         : 2.8.6 (dt dec pq3 ext lo64)\r\njinja2           : 2.11.3\r\nIPython          : 7.24.1\r\npandas_datareader: None\r\nbs4              : 4.9.3\r\nbottleneck       : 1.3.2\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.4.2\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.7\r\npandas_gbq       : None\r\npyarrow          : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.6.3\r\nsqlalchemy       : 1.4.17\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : 2.0.1\r\nxlwt             : None\r\nnumba            : None\r\n\r\n</details>\r\n',
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42295/comments',
#   'created_at': '2021-06-29T08:58:21Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42295/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42295',
#   'id': 932388491,
#   'labels': [{'color': 'e10c02',
#     'default': False,
#     'description': None,
#     'id': 76811,
#     'name': 'Bug',
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug'},
#    {'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member',
#     'id': 1954720290,
#     'name': 'Needs Triage',
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42295/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'node_id': 'MDU6SXNzdWU5MzIzODg0OTE=',
#   'number': 42295,
#   'performed_via_github_app': None,
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'BUG: df.where() inconsistently casts columns to integers',
#   'updated_at': '2021-06-30T07:15:43Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42295',
#   'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/20555592?v=4',
#    'events_url': 'https://api.github.com/users/nicolaslegrand91/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/nicolaslegrand91/followers',
#    'following_url': 'https://api.github.com/users/nicolaslegrand91/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/nicolaslegrand91/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/nicolaslegrand91',
#    'id': 20555592,
#    'login': 'nicolaslegrand91',
#    'node_id': 'MDQ6VXNlcjIwNTU1NTky',
#    'organizations_url': 'https://api.github.com/users/nicolaslegrand91/orgs',
#    'received_events_url': 'https://api.github.com/users/nicolaslegrand91/received_events',
#    'repos_url': 'https://api.github.com/users/nicolaslegrand91/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/nicolaslegrand91/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/nicolaslegrand91/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/nicolaslegrand91'}}]

# %%
dados[0]['title']
# Out:
# 'DEPR: ignoring missing labels when indexing on MultiIndex level'

# %%
lista_bugs = pd.DataFrame(dados, columns=['number', 'title','labels', 'state'])

# %%
lista_bugs
# Out:
#     number  ... state
# 0    42351  ...  open
# 1    42350  ...  open
# 2    42349  ...  open
# 3    42347  ...  open
# 4    42346  ...  open
# 5    42345  ...  open
# 6    42343  ...  open
# 7    42342  ...  open
# 8    42340  ...  open
# 9    42339  ...  open
# 10   42338  ...  open
# 11   42335  ...  open
# 12   42333  ...  open
# 13   42332  ...  open
# 14   42331  ...  open
# 15   42329  ...  open
# 16   42328  ...  open
# 17   42326  ...  open
# 18   42325  ...  open
# 19   42319  ...  open
# 20   42316  ...  open
# 21   42314  ...  open
# 22   42311  ...  open
# 23   42309  ...  open
# 24   42307  ...  open
# 25   42305  ...  open
# 26   42304  ...  open
# 27   42303  ...  open
# 28   42301  ...  open
# 29   42295  ...  open
#
# [30 rows x 4 columns]

# %% [markdown]
# ## **Manipulando dados de banco de dados:**

# %%
import sqlite3

# %%
query = """
        CREATE TABLE teste(
          a VARCHAR(20),
          b VARCHAR(20),
          c FLOAT,
          d INT);"""

# %%
con = sqlite3.connect('/content/drive/MyDrive/Data Science/Python para Analise de Dados/mydata.sqlite', timeout=10)

# %%
con.commit()

# %%
dados_query = [('São Paulo', 'Mogi das Cruzes', 1.25, 6),
               ('Minas Gerais', 'Belo Horizonte', 2.6, 3), 
               ('Rio Grande do Sul', 'Pelotas', 1.7, 5)]
stmt = "INSERT INTO teste VALUES(?, ?, ?, ?)"

# %%
con.executemany(stmt, dados_query)

# %%
tabela = con.execute('select * from teste')
linhas = tabela.fetchall()
linhas
# Out:
# [('São Paulo', 'Mogi das Cruzes', 1.25, 6),
#  ('Minas Gerais', 'Belo Horizonte', 2.6, 3),
#  ('Rio Grande do Sul', 'Pelotas', 1.7, 5)]

# %%
colunas = tabela.description
colunas
# Out:
# (('a', None, None, None, None, None, None),
#  ('b', None, None, None, None, None, None),
#  ('c', None, None, None, None, None, None),
#  ('d', None, None, None, None, None, None))

# %%
df_sql = pd.DataFrame(linhas, columns=[x[0] for x in colunas])
df_sql
# Out:
#                    a                b     c  d
# 0          São Paulo  Mogi das Cruzes  1.25  6
# 1       Minas Gerais   Belo Horizonte  2.60  3
# 2  Rio Grande do Sul          Pelotas  1.70  5
