# %%
import nltk
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sid = SentimentIntensityAnalyzer()

# %%
df = pd.read_json('azure_evandro.json')
df.replace(r'\n', '', regex=True, inplace=True)
df.replace(r'\xa0', '', regex=True, inplace=True)
df.replace(r'\r', '', regex=True, inplace=True)
df.head()
# Out:
#                                                Title  \
# 0  Advancing service resilience in Azure Active D...
# 1  Join Azure at the Design Automation Conference...
# 2  Build real-time web apps with Azure Web PubSub...
# 3  Bringing commercial innovations in chip design...
# 4  Microsoft and AT&T are accelerating the enterp...
#
#                           Date       Contributor  \
# 0  Posted on November 22, 2021  Mark Russinovich
# 1  Posted on November 16, 2021     Rachel Pruitt
# 2  Posted on November 16, 2021        Yulin  Shi
# 3  Posted on November 17, 2021         Tom Keane
# 4  Posted on November 17, 2021      Jason Zander
#
#                                              Content  \
# 0  “Continuing our Advancing Reliability blog ser...
# 1  The Azure High-Performance Computing (HPC) sol...
# 2  Push data in real-time with Azure Web PubSub S...
# 3  Semiconductors and microelectronics are some o...
# 4  Today, we find ourselves at a pivotal moment t...
#
#                                                 link  \
# 0  https://azure.microsoft.com/en-us/blog/advanci...
# 1  https://azure.microsoft.com/en-us/blog/join-az...
# 2  https://azure.microsoft.com/en-us/blog/build-r...
# 3  https://azure.microsoft.com/en-us/blog/bringin...
# 4  https://azure.microsoft.com/en-us/blog/microso...
#
#                                                 Role
# 0  Chief Technology Officer and Technical Fellow,...
# 1  Product Marketing Manager, Azure Marketing, HP...
# 2                          Principal Program Manager
# 3  Corporate Vice President, Azure Global, Micros...
# 4          Executive Vice President, Microsoft Azure

# %%
df.isnull().sum()
# Out:
# Title             0
# Date              0
# Contributor    1276
# Content           0
# link              0
# Role           1276
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
sid.polarity_scores(df.iloc[0]['Content'])
# Out:
# {'neg': 0.03, 'neu': 0.848, 'pos': 0.122, 'compound': 0.9986}

# %%
df.Content[0]
# Out:
# '“Continuing our Advancing Reliability blog series, which highlights key updates and initiatives related to improving the reliability of the Azure platform and services, today we turn our focus to Azure Active Directory (Azure AD). We laid out the core availability principles of Azure AD as part of this series back in 2019 so I’ve asked Nadim Abdo, Corporate Vice President, Engineering, to provide the latest update on how our engineering teams are working to ensure the reliability of our identity and access management services that are so critical to customers and partners.”—Mark Russinovich, CTO, AzureThe most critical promise of our identity services is ensuring that every user can access the apps and services they need without interruption. We’ve been strengthening this promise to you through a multi-layered approach, leading to our improved promise of 99.99 percent authentication uptime for Azure Active Directory (Azure AD). Today, I am excited to share a deep dive into generally available technology that allows Azure AD to achieve even higher levels of resiliency.The Azure AD backup authentication service transparently and automatically handles authentications for supported workloads when the primary Azure AD service is unavailable. It adds an additional layer of resilience on top of the multiple levels of redundancy in Azure AD. You can think of it as a backup generator or uninterrupted power supply designed to provide additional fault tolerance while staying completely transparent and automatic to you. This system operates in the Microsoft cloud but on separate and decorrelated systems and network paths from the primary Azure AD system. This means that it can continue to operate in case of service, network, or capacity issues across many Azure AD and dependent Azure services.What workloads are covered by the service?This service has been protecting Outlook Web Access and SharePoint Online workloads since 2019. Earlier this year we completed backup support for applications running on desktops and mobile devices, or “native” apps. All Microsoft native apps including Office 365 and Teams, plus non-Microsoft and customer-owned applications running natively on devices are now covered. No special action or configuration changes are required to receive the backup authentication coverage.Starting at the end of 2021, we will begin rolling out support for more web-based applications. We will be phasing in apps using Open ID Connect, starting with Microsoft web apps like Teams Online and Office 365, followed by customer-owned web apps that use Open ID Connect and Security Assertion Markup Language (SAML).How does the service work?When a failure of the Azure AD primary service is detected, the backup authentication service automatically engages, allowing the user’s applications to keep working. As the primary service recovers, authentication requests are re-routed back to the primary Azure AD service. The backup authentication service operates in two modes:Normal mode: The backup service stores essential authentication data during normal operating conditions. Successful authentication responses from Azure AD to dependent apps generate session-specific data that is securely stored by the backup service for up to three days. The authentication data is specific to a device-user-app-resource combination and represents a snapshot of a successful authentication at a point in time.Outage mode: Any time an authentication request fails unexpectedly, the Azure AD gateway automatically routes it to the backup service. It then authenticates the request, verifies artifacts presented are valid (such as, refresh token, and session cookie), and looks for a strict session match in the previously stored data. An authentication response, consistent with what the primary Azure AD system would have generated, is then sent to the application. Upon recovery, traffic is dynamically re-routed back to the primary Azure AD service.Routing to the backup servi ...

# %%
df['Scores'] = df['Content'].apply(lambda content: sid.polarity_scores(content))
df.head()
# Out:
#                                                Title  \
# 0  Advancing service resilience in Azure Active D...
# 1  Join Azure at the Design Automation Conference...
# 2  Build real-time web apps with Azure Web PubSub...
# 3  Bringing commercial innovations in chip design...
# 4  Microsoft and AT&T are accelerating the enterp...
#
#                           Date       Contributor  \
# 0  Posted on November 22, 2021  Mark Russinovich
# 1  Posted on November 16, 2021     Rachel Pruitt
# 2  Posted on November 16, 2021        Yulin  Shi
# 3  Posted on November 17, 2021         Tom Keane
# 4  Posted on November 17, 2021      Jason Zander
#
#                                              Content  \
# 0  “Continuing our Advancing Reliability blog ser...
# 1  The Azure High-Performance Computing (HPC) sol...
# 2  Push data in real-time with Azure Web PubSub S...
# 3  Semiconductors and microelectronics are some o...
# 4  Today, we find ourselves at a pivotal moment t...
#
#                                                 link  \
# 0  https://azure.microsoft.com/en-us/blog/advanci...
# 1  https://azure.microsoft.com/en-us/blog/join-az...
# 2  https://azure.microsoft.com/en-us/blog/build-r...
# 3  https://azure.microsoft.com/en-us/blog/bringin...
# 4  https://azure.microsoft.com/en-us/blog/microso...
#
#                                                 Role  \
# 0  Chief Technology Officer and Technical Fellow,...
# 1  Product Marketing Manager, Azure Marketing, HP...
# 2                          Principal Program Manager
# 3  Corporate Vice President, Azure Global, Micros...
# 4          Executive Vice President, Microsoft Azure
#
#                                               Scores
# 0  {'neg': 0.03, 'neu': 0.848, 'pos': 0.122, 'com...
# 1  {'neg': 0.016, 'neu': 0.881, 'pos': 0.103, 'co...
# 2  {'neg': 0.0, 'neu': 0.852, 'pos': 0.148, 'comp...
# 3  {'neg': 0.017, 'neu': 0.779, 'pos': 0.204, 'co...
# 4  {'neg': 0.008, 'neu': 0.809, 'pos': 0.182, 'co...

# %%
df['Compound'] = df['Scores'].apply(lambda d: d['compound'])
df['Overall Score'] = df['Compound'].apply(lambda score: 'POS' if score >=0 else 'NEG')
df.head()
# Out:
#                                                Title  \
# 0  Advancing service resilience in Azure Active D...
# 1  Join Azure at the Design Automation Conference...
# 2  Build real-time web apps with Azure Web PubSub...
# 3  Bringing commercial innovations in chip design...
# 4  Microsoft and AT&T are accelerating the enterp...
#
#                           Date       Contributor  \
# 0  Posted on November 22, 2021  Mark Russinovich
# 1  Posted on November 16, 2021     Rachel Pruitt
# 2  Posted on November 16, 2021        Yulin  Shi
# 3  Posted on November 17, 2021         Tom Keane
# 4  Posted on November 17, 2021      Jason Zander
#
#                                              Content  \
# 0  “Continuing our Advancing Reliability blog ser...
# 1  The Azure High-Performance Computing (HPC) sol...
# 2  Push data in real-time with Azure Web PubSub S...
# 3  Semiconductors and microelectronics are some o...
# 4  Today, we find ourselves at a pivotal moment t...
#
#                                                 link  \
# 0  https://azure.microsoft.com/en-us/blog/advanci...
# 1  https://azure.microsoft.com/en-us/blog/join-az...
# 2  https://azure.microsoft.com/en-us/blog/build-r...
# 3  https://azure.microsoft.com/en-us/blog/bringin...
# 4  https://azure.microsoft.com/en-us/blog/microso...
#
#                                                 Role  \
# 0  Chief Technology Officer and Technical Fellow,...
# 1  Product Marketing Manager, Azure Marketing, HP...
# 2                          Principal Program Manager
# 3  Corporate Vice President, Azure Global, Micros...
# 4          Executive Vice President, Microsoft Azure
#
#                                               Scores  Compound Overall Score
# 0  {'neg': 0.03, 'neu': 0.848, 'pos': 0.122, 'com...    0.9986           POS
# 1  {'neg': 0.016, 'neu': 0.881, 'pos': 0.103, 'co...    0.9966           POS
# 2  {'neg': 0.0, 'neu': 0.852, 'pos': 0.148, 'comp...    0.9971           POS
# 3  {'neg': 0.017, 'neu': 0.779, 'pos': 0.204, 'co...    0.9975           POS
# 4  {'neg': 0.008, 'neu': 0.809, 'pos': 0.182, 'co...    0.9996           POS

# %%
df[df['Overall Score'] == 'NEG']
# Out:
#                                                   Title  \
# 99    Windows Azure Sync Service Demo Available for ...
# 240   Data Series: Introducing Locally Redundant Sto...
# 497                 Update on the ASP.NET Vulnerability
# 523   Video: SQL Server to SQL Azure Synchronization...
# 1026  Service Healing - Auto-recovery of Virtual Mac...
# ...                                                 ...
# 5813  Azure DDoS Protection—2021 Q1 and Q2 DDoS atta...
# 5954  Retrieve platform notification system error de...
# 5966  Azure SQL Database Threat Detection, your buil...
# 5976       Detecting threats with Azure Security Center
# 6010  Updated Azure business continuity technical gu...
#
#                            Date      Contributor  \
# 99    Posted on October 8, 2010      Mike Schutz
# 240      Posted on June 8, 2012      Brad Calder
# 497   Posted on October 1, 2010      Mike Schutz
# 523   Posted on August 31, 2010      Mike Schutz
# 1026    Posted on April 7, 2015  Jeelani Mohamed
# ...                         ...              ...
# 5813  Posted on August 12, 2021      Alethea Toh
# 5954  Posted on August 25, 2016          Mimi Xu
# 5966  Posted on August 17, 2016     Ron Matchoro
# 5976     Posted on May 17, 2016     Tomer Teller
# 6010    Posted on June 16, 2016       Adam Glick
#
#                                                 Content  \
# 99    [This article was contributed by the SQL Azure...
# 240   We are excited to offer two types of redundant...
# 497   A security update has been released which addr...
# 523   [This article was contributed by the SQL Azure...
# 1026  Ever since its inception and public preview al...
# ...                                                 ...
# 5813  This blog post was co-authored by Amir Dahan, ...
# 5954  We enabled Platform Notification System Feedba...
# 5966  Azure SQL Database Threat Detection has been i...
# 5976  The past five years have seen the emergence of...
# 6010  We are pleased to announce the update to the r...
#
#                                                    link  \
# 99    https://azure.microsoft.com/en-us/blog/windows...
# 240   https://azure.microsoft.com/en-us/blog/data-se...
# 497   https://azure.microsoft.com/en-us/blog/update-...
# 523   https://azure.microsoft.com/en-us/blog/video-s...
# 1026  https://azure.microsoft.com/en-us/blog/service...
# ...                                                 ...
# 5813  https://azure.microsoft.com/en-us/blog/azure-d...
# 5954  https://azure.microsoft.com/en-us/blog/retriev...
# 5966  https://azure.microsoft.com/en-us/blog/azure-s...
# 5976  https://azure.microsoft.com/en-us/blog/detecti...
# 6010  https://azure.microsoft.com/en-us/blog/updated...
#
#                                                    Role  \
# 99            General Manager, Cloud Platform Marketing
# 240   CVP- Windows Azure Development, US - WinAzure ...
# 497           General Manager, Cloud Platform Marketing
# 523           General Manager, Cloud Platform Marketing
# 1026                   Program Manager, Microsoft Azure
# ...                                                 ...
# 5813                  Program Manager, Azure Networking
# 5954                 Program Manager, Azure App Service
# 5966        Principal Program Manager, Microsoft Azure
# 5976                    Senior Security Program Manager
# 6010              Sr. Program Manager, Azure Resiliency
#
#                                                  Scores  Compound  \
# 99    {'neg': 0.031, 'neu': 0.922, 'pos': 0.046, 'co...   -0.1372
# 240   {'neg': 0.047, 'neu': 0.907, 'pos': 0.046, 'co...   -0.1406
# 497   {'neg': 0.039, 'neu': 0.929, 'pos': 0.032, 'co...   -0.0258
# 523   {'neg': 0.028, 'neu': 0.951, 'pos': 0.021, 'co...   -0.1531
# 1026  {'neg': 0.075, 'neu': 0.878, 'pos': 0.046, 'co...   -0.9885
# ...                                                 ...       ...
# 5813  {'neg': 0.129, 'neu': 0.801, 'pos': 0.07, 'com...   -0.9988
# 5954  {'neg': 0.091, 'neu': 0.849, 'pos': 0.059, 'co...   -0.9611
# 5966  {'neg': 0.137, 'neu': 0.755, 'pos': 0.108, 'co...   -0.9874
# 5976  {'neg': 0.181, 'neu': 0.723, 'pos': 0.095, 'co...   -0.9981
# 6010  {'neg': 0.13, 'neu': 0.733, 'pos': 0.137, 'com...   -0.1531
#
#      Overall Score
# 99             NEG
# 240            NEG
# 497            NEG
# 523            NEG
# 1026           NEG
# ...            ...
# 5813           NEG
# 5954           NEG
# 5966           NEG
# 5976           NEG
# 6010           NEG
#
# [72 rows x 9 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_df=.9, min_df=.1, stop_words= 'english')
dtm = cv.fit_transform(df['Content'])

# %%
dtm
# Out:
# <4774x511 sparse matrix of type '<class 'numpy.int64'>'
# 	with 487695 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import LatentDirichletAllocation
LDA = LatentDirichletAllocation(n_components=10)
LDA.fit(dtm)
# Out:
# LatentDirichletAllocation()

# %%
first_topic = LDA.components_[0]
first_topic.argsort()
# Out:
# array([136, 235, 492, 444, 233, 133, 223, 283, 189,  28, 180, 321,  17,
#         79, 184,  36, 148,  78, 232, 350, 237,  34, 111, 247, 210, 241,
#        276, 401,  32, 207,  70,  77, 134, 319, 129, 459, 431, 209, 402,
#        277, 328, 449, 344, 229, 456, 131, 115, 122, 175, 454, 296, 192,
#        201, 493, 348, 423, 317, 414, 432, 316, 337, 130,  31,  59, 159,
#        395, 107, 225, 208,  57,  49, 147, 224, 396,   3, 308, 498,  83,
#        378, 194, 254, 132,  52, 142, 257, 499, 497, 123, 368, 464, 425,
#        320, 455, 375,  86, 307, 343, 158, 143, 114, 226, 285, 338, 369,
#        206, 391, 487, 409,   7, 211, 429, 392, 349, 468, 506, 334, 266,
#        355, 195, 389, 306, 360, 315, 144,  73, 230, 510, 256,  15, 356,
#        377, 452, 450, 471, 234, 439,  66, 440, 199,  75,  21,  91, 112,
#         55, 253,  44, 166,  51, 371,  47, 309, 326, 120, 364,  65,  81,
#        183, 410, 399, 481, 228, 330, 146, 264, 494, 240, 427, 406, 202,
#        483, 363, 281, 405, 387, 436, 421, 351,  82, 445,   9, 346,  14,
#         48, 325, 176, 486, 190, 332,  95,  11,  72, 248, 289, 185, 361,
#        217, 420, 407, 161,  33, 323,  76, 311, 113, 370, 220, 262, 384,
#        390,  80, 196, 299, 275, 465, 457, 472, 141, 458, 103, 488, 362,
#         94,  90, 372, 216, 475, 408, 418, 495, 404, 124,  27, 121, 105,
#         84, 157, 502, 267, 417,  56, 496, 329, 473, 474,  92, 268, 245,
#        270, 354, 222, 137, 251, 509, 485, 342, 327, 197, 102, 438, 284,
#        437, 501,  29, 269,  87, 503, 453, 335,  62, 336, 125, 238,  40,
#         61, 294,  26, 507, 236,  10, 116, 288, 213, 117, 155, 214, 434,
#        383, 193, 160, 278, 179, 255,  98, 376, 469, 127, 212, 279,  50,
#        162, 301, 489,  89, 282, 484, 419,  41, 500, 118, 263, 382,  67,
#        479, 259, 250, 467, 345, 100, 442, 200, 188, 178,  19, 292, 322,
#         88, 181, 380,   2, 379,   6, 476, 352, 168,  60, 381, 167,  42,
#         64, 347,  71,  74, 198, 365,  63, 138, 260, 231, 426,  16, 174,
#        430, 145, 274,  22, 366,  35,  97, 106, 428,  24, 462, 135, 239,
#        182, 313,  25, 333, 394, 215, 154, 108,   0,  93,  18, 149, 119,
#        271,  46, 303, 273, 435, 451, 393, 397, 295, 358, 443, 470, 339,
#        219, 448,   8, 478, 312, 416, 126, 388, 191, 466, 139, 156,  96,
#        314, 252, 244, 480, 205, 104,  54, 403, 153,  20,   1, 400,  43,
#        258, 165, 385, 293, 152, 151, 447, 490, 504, 461, 310, 305, 101,
#        304, 227, 491, 177, 300, 302, 508, 413,  12, 386, 290, 261, 318,
#        221, 331, 424, 204, 171, 280,  58, 150, 218, 128, 242, 412, 187,
#        163, 164, 353,  53,  13, 367, 357, 246,  68, 140,  30, 170,  85,
#        291, 249, 415, 272, 265,  23, 359, 287, 477, 169,  39, 463,  99,
#        422, 286, 186, 243, 482, 505, 341, 460, 373, 203,   5, 297, 446,
#          4, 433,  69, 109, 411, 173, 398, 172, 374, 298, 340,  38,  45,
#         37, 324, 110, 441], dtype=int64)

# %%
top_ten = first_topic.argsort()[-10:]
for index in top_ten:
    print(cv.get_feature_names_out()[index])
# Out:
# file
# regions
# new
# preview
# available
# blob
# availability
# performance
# data
# storage

# %%
import sys

orig_stdout = sys.stdout
f = open(
    'df.txt', 'w'
)
sys.stdout = f


for index, topic in enumerate(LDA.components_):
    dataframe = pd.DataFrame(columns=[f'THE TOP 15 WORDS FOR TOPIC #{index}'], data=[cv.get_feature_names_out()[index] for index in topic.argsort()[-15:]])
    print(dataframe)

sys.stdout = orig_stdout
f.close()

# %%
df2 = pd.read_table('df.txt', header=None)
import numpy as np
arr = np.array(df2)
dataframe = pd.DataFrame(arr.reshape((10, 16))).T
headers = dataframe.iloc[0]
new_df = pd.DataFrame(data=dataframe.values[1:], columns=headers)
new_df
# Out:
# 0      THE TOP 15 WORDS FOR TOPIC #0     THE TOP 15 WORDS FOR TOPIC #1  \
# 0   0                        cluster  0                    development
# 1   1                      customers  1                            new
# 2   2                        service  2                          stack
# 3   3                          files  3                            web
# 4   4                          scale  4                         visual
# 5   5                           file  5                         studio
# 6   6                        regions  6                           code
# 7   7                            new  7                   applications
# 8   8                        preview  8                       services
# 9   9                      available  9                          build
# 10  10                          blob  10                    developers
# 11  11                  availability  11                          apps
# 12  12                   performance  12                   application
# 13  13                          data  13                       service
# 14  14                       storage  14                           app
#
# 0      THE TOP 15 WORDS FOR TOPIC #2     THE TOP 15 WORDS FOR TOPIC #3  \
# 0   0                            new  0                      solutions
# 1   1                            use  1                            use
# 2   2                         create  2                           time
# 3   3                          linux  3                          using
# 4   4                          using  4                       services
# 5   5                           site  5                        digital
# 6   6                         server  6                            new
# 7   7                        network  7                         models
# 8   8                        windows  8                      microsoft
# 9   9                       recovery  9                          model
# 10  10                       machine  10                         video
# 11  11                           vms  11                       machine
# 12  12                      machines  12                          edge
# 13  13                            vm  13                      learning
# 14  14                       virtual  14                            ai
#
# 0      THE TOP 15 WORDS FOR TOPIC #4     THE TOP 15 WORDS FOR TOPIC #5  \
# 0   0                           help  0                          using
# 1   1                 infrastructure  1                      connected
# 2   2                      solutions  2                       security
# 3   3                     enterprise  3                           time
# 4   4                        service  4                        service
# 5   5                       platform  5                        central
# 6   6                     management  6                      solutions
# 7   7                       business  7                            new
# 8   8                   applications  8                         events
# 9   9                            new  9                       solution
# 10  10                      services  10                         event
# 11  11                      security  11                           hub
# 12  12                     customers  12                       devices
# 13  13                     microsoft  13                        device
# 14  14                         cloud  14                           iot
#
# 0      THE TOP 15 WORDS FOR TOPIC #6     THE TOP 15 WORDS FOR TOPIC #7  \
# 0   0                            new  0                        queries
# 1   1                          query  1                     processing
# 2   2                        managed  2                          power
# 3   3                       instance  3                           real
# 4   4                          using  4                          store
# 5   5                    application  5                            sql
# 6   6                           data  6                            big
# 7   7                        traffic  7                            use
# 8   8                      migration  8                       analysis
# 9   9                        service  9                          using
# 10  10                     databases  10                      insights
# 11  11                   performance  11                         query
# 12  12                        server  12                          time
# 13  13                      database  13                     analytics
# 14  14                           sql  14                          data
#
# 0      THE TOP 15 WORDS FOR TOPIC #8     THE TOP 15 WORDS FOR TOPIC #9
# 0   0                           need  0                        support
# 1   1                          click  1                            net
# 2   2                    application  2                       services
# 3   3                     automation  3                            web
# 4   4                         create  4                      container
# 5   5                           view  5                            key
# 6   6                          using  6                         create
# 7   7                     powershell  7                            sdk
# 8   8                            use  8                        version
# 9   9                      resources  9                           code
# 10  10                          cost  10                           use
# 11  11                        portal  11                         using
# 12  12                    management  12                           new
# 13  13                      resource  13                           api
# 14  14                           new  14                       service

# %%
new_df.to_excel('azure_topic.xlsx', index=False)

# %%
topic_results = LDA.transform(dtm)
topic_results[0].argmax()
# Out:
# 9

# %%
df['Topic'] = topic_results.argmax(axis=1)

# %%
df.head()
# Out:
#                                                Title  \
# 0  Advancing service resilience in Azure Active D...
# 1  Join Azure at the Design Automation Conference...
# 2  Build real-time web apps with Azure Web PubSub...
# 3  Bringing commercial innovations in chip design...
# 4  Microsoft and AT&T are accelerating the enterp...
#
#                           Date       Contributor  \
# 0  Posted on November 22, 2021  Mark Russinovich
# 1  Posted on November 16, 2021     Rachel Pruitt
# 2  Posted on November 16, 2021        Yulin  Shi
# 3  Posted on November 17, 2021         Tom Keane
# 4  Posted on November 17, 2021      Jason Zander
#
#                                              Content  \
# 0  “Continuing our Advancing Reliability blog ser...
# 1  The Azure High-Performance Computing (HPC) sol...
# 2  Push data in real-time with Azure Web PubSub S...
# 3  Semiconductors and microelectronics are some o...
# 4  Today, we find ourselves at a pivotal moment t...
#
#                                                 link  \
# 0  https://azure.microsoft.com/en-us/blog/advanci...
# 1  https://azure.microsoft.com/en-us/blog/join-az...
# 2  https://azure.microsoft.com/en-us/blog/build-r...
# 3  https://azure.microsoft.com/en-us/blog/bringin...
# 4  https://azure.microsoft.com/en-us/blog/microso...
#
#                                                 Role  \
# 0  Chief Technology Officer and Technical Fellow,...
# 1  Product Marketing Manager, Azure Marketing, HP...
# 2                          Principal Program Manager
# 3  Corporate Vice President, Azure Global, Micros...
# 4          Executive Vice President, Microsoft Azure
#
#                                               Scores  Compound Overall Score  \
# 0  {'neg': 0.03, 'neu': 0.848, 'pos': 0.122, 'com...    0.9986           POS
# 1  {'neg': 0.016, 'neu': 0.881, 'pos': 0.103, 'co...    0.9966           POS
# 2  {'neg': 0.0, 'neu': 0.852, 'pos': 0.148, 'comp...    0.9971           POS
# 3  {'neg': 0.017, 'neu': 0.779, 'pos': 0.204, 'co...    0.9975           POS
# 4  {'neg': 0.008, 'neu': 0.809, 'pos': 0.182, 'co...    0.9996           POS
#
#    Topic
# 0      9
# 1      4
# 2      1
# 3      4
# 4      3

# %%
df.to_excel('azure_final.xlsx', index=False)
# Out:
# C:\Users\mvmoraes\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:1168: UserWarning: Ignoring URL 'https://docs.microsoft.com/en-us/azure/documentdb/documentdb-nosql-local-emulatorAs%20of%20May%2010th%202017,Azure%20Cosmos%20DB%20is%20Microsoft’s%20globally%20distributed%20multi-model%20database.%20Azure%20Cosmos%20DB%20was%20built%20from%20the%20ground%20up%20with%20global%20distribution%20and%20horizontal%20scale%20at%20its%20core.%20It%20offers%20turnkey%20global%20distribution%20across%20any%20number%20of%20Azure%20regions%20by%20transparently%20scaling%20and%20replicating%20your%20data%20wherever%20your%20users%20are.%20Elastically%20scale%20throughput%20and%20storage%20worldwide,%20and%20pay%20only%20for%20the%20throughput%20and%20storage%20you%20need.%20Azure%20Cosmos%20DB%20guarantees%20single-digit-millisecond%20latencies%20at%20the%2099th%20percentile%20anywhere%20in%20the%20world,%20offers%20multiple%20well-defined%20consistency%20models%20to%20fine-tune%20performance,%20and%20guarantees%20high%20availability%20with%20multi-homing%20capabilities—all%20backed%20by%20industry%20leading%20service%20level%20agreements%20(SLAs).Azure%20Cosmos%20DB%20is%20truly%20schema-agnostic;%20it%20automatically%20indexes%20all%20the%20data%20without%20requiring%20you%20to%20deal%20with%20schema%20and%20index%20management.%20It’s%20also%20multi-model,%20natively%20supporting%20document,%20key-value,%20graph,%20and%20column-family%20data%20models.%20With%20Azure%20Cosmos%20DB,%20you%20can%20access%20your%20data%20using%20APIs%20of%20your%20choice,%20as%20DocumentDB%20SQL%20(document),%20MongoDB%20(document),%20Azure%20Table%20Storage%20(key-value),%20and%20Gremlin%20(graph)%20are%20all%20natively%20supported.This%20week%20at%20Microsoft%20Data%20Amp%20we%20covered%20how%20you%20can%20harness%20the%20incredible%20power%20of%20data%20using%20Microsoft’s%20latest%20innovations%20in%20its%20Data%20Platform.%20One%20of%20the%20key%20pieces%20in%20the%20Data%20Platform%20is%20Azure%20Cosmos%20DB,%20Microsoft’s%20globally%20distributed%20multi-model%20database%20service.%20Azure%20Cosmos%20DB%20is%20used%20virtually%20ubiquitously%20as%20a%20backend%20for%20first-party%20Microsoft%20services%20for%20many%20years.In%20this%20blog,%20we%20cover%20case%20studies%20of%20first-party%20applications%20of%20Azure%20Cosmos%20DB%20by%20the%20Windows,%20Universal%20Store,%20and%20Azure%20IoT%20Hub%20teams,%20and%20how%20these%20teams%20could%20harness%20the%20scalability,%20low%20latency,%20and%20flexibility%20benefits%20of%20Azure%20Cosmos%20DB%20to%20innovate%20and%20bring%20business%20value%20to%20their%20services.Microsoft%20DnA:%20How%20Microsoft%20uses%20error%20reporting%20and%20diagnostics%20to%20improve%20WindowsThe%20Windows%20Data%20and%20Analytics%20(DnA)%20team%20in%20Microsoft%20implements%20the%20crash%20reporting%20technology%20for%20Windows.%20One%20of%20their%20components%20runs%20as%20a%20Windows%20Service%20in%20every%20Windows%20device.%20Whenever%20an%20application%20stops%20responding%20on%20a%20user's%20desktop,%20Windows%20collects%20post-error%20debug%20information%20and%20prompts%20the%20user%20to%20ask%20if%20they’re%20interested%20in%20finding%20a%20solution%20to%20the%20error.%20If%20the%20user%20accepts,%20the%20dump%20is%20sent%20over%20the%20Internet%20to%20the%20DnA%20service.%20When%20a%20dump%20reaches%20the%20service,%20it%20is%20analyzed%20and%20a%20solution%20is%20sent%20back%20to%20the%20user%20when%20one%20is%20available.Windows%20error%20reporting%20diagnostic%20informationWindows'%20need%20for%20fast%20key-value%20lookupsIn%20DnA’s%20terminology,%20crash%20reports%20are%20organized%20into%20“buckets”.%20Each%20bucket%20is%20used%20to%20classify%20an%20issue%20by%20key%20attributes%20such%20as%20Application%20Name,%20Application%20Version,%20Module%20Name,%20Module%20Version,%20and%20OS%20Exception%20code.%20Each%20bucket%20contains%20crash%20reports%20that%20are%20caused%20by%20the%20same%20bug.%20With%20t ...
#   warn("Ignoring URL '%s' with link or location/anchor > %d "
