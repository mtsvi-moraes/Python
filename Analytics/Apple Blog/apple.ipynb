# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from collections import Counter
from string import punctuation
from matplotlib import rcParams
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
df = pd.read_json('apple2.json')
df.replace(r'\n', '', regex=True, inplace=True)
df.replace(r'\xa0', '', regex=True, inplace=True)
df.replace(r'\r', '', regex=True, inplace=True)
df.replace(r'<h4>', '', inplace=True)
df.replace(r's:,', '', inplace=True)
df.replace(r'\n', '', inplace=True)
df.replace(r'\t', '', inplace=True)
df
# Out:
#                                                   Title       Date  \
# 0     Apple charges forward to 2030 carbon neutral g... 2021-10-27
# 1             Apple introduces AppleBusiness Essentials 2021-11-10
# 2                      Holiday season kicks off atApple 2021-11-09
# 3                  Apple Reports Fourth Quarter Results 2021-10-28
# 4         Apple honors and celebrates American veterans 2021-11-11
# ...                                                 ...        ...
# 1815              Apple Teams with Kanisa for e-Service 2000-04-05
# 1816  Apple’s QuickTime 4 Downloads Top 32 Million a... 2000-04-05
# 1817  Apple Acquires DVD Authoring Technology, Produ... 2000-04-10
# 1818  Apple Unveils Mac OS X and Internet Strategy a... 2000-01-05
# 1819  Apple's QuickTime TV Network Scores Super Bowl... 2000-01-24
#
#                                             Contributor  \
# 0                   [Keri Fulton, Apple Media Helpline]
# ...

# %%
cont = pd.DataFrame(df['Contributor'].tolist(), columns=[
    'col1', 'col2', 'col3', 'col4', 'col5', 'col6'
])
cont.replace('None', np.nan, inplace=True)
cont['Contributors'] = cont[[
    'col1', 'col2', 'col3', 'col4', 'col5', 'col6'
]].apply(
    lambda x: ', '.join(x[x.notnull()]
), axis = 1)
dff = pd.concat([df, cont['Contributors']], axis=1)
dff.drop(['Contributor'], axis=1, inplace=True)
dff= dff[['Title', 'Date', 'Contributors', 'Content', 'link', 'Role']]
dff.replace('PRESS RELEASE|UPDATE', '', regex =True, inplace=True)
dff
# Out:
#                                                   Title       Date  \
# 0     Apple charges forward to 2030 carbon neutral g... 2021-10-27
# 1             Apple introduces AppleBusiness Essentials 2021-11-10
# 2                      Holiday season kicks off atApple 2021-11-09
# 3                  Apple Reports Fourth Quarter Results 2021-10-28
# 4         Apple honors and celebrates American veterans 2021-11-11
# ...                                                 ...        ...
# 1815              Apple Teams with Kanisa for e-Service 2000-04-05
# 1816  Apple’s QuickTime 4 Downloads Top 32 Million a... 2000-04-05
# 1817  Apple Acquires DVD Authoring Technology, Produ... 2000-04-10
# 1818  Apple Unveils Mac OS X and Internet Strategy a... 2000-01-05
# 1819  Apple's QuickTime TV Network Scores Super Bowl... 2000-01-24
#
#                                            Contributors  \
# 0                     Keri Fulton, Apple Media Helpline
# ...

# %%
def get_hotwords(text):
    result = []
    pos_tag = ['PROPN', 'ADJ', 'NOUN']
    doc = nlp(text.lower())
    for token in doc:
        
        if(token.text in nlp.Defaults.stop_words or token.text in punctuation):
            continue
        
        elif(token.pos_ in pos_tag):
            result.append(token.text)
                
    return result

# %%
message_text = str(df.Title.values)
output = get_hotwords(message_text)
words = [x for x in Counter(output).most_common(9)]

# %%
words
# Out:
# [('apple', 5),
#  ('carbon', 1),
#  ('neutral', 1),
#  ('goal', 1),
#  ('gigawatts', 1),
#  ('clean', 1),
#  ('power', 1),
#  ('supplier', 1),
#  ('commitments', 1)]

# %%
df2 = pd.DataFrame(words, columns =['Keyword', 'Amount'])
df2.to_csv('keyword_amount.csv', index=False)

# %%
doc = list(nlp(message_text).noun_chunks)

# %%
import sys

orig_stdout = sys.stdout
f = open(
    'apple.txt', 'w'
)
sys.stdout = f


for token in doc:
    if 'Apple' in str(token):
        print(token)

sys.stdout = orig_stdout
f.close()

# %%
df1 = pd.read_table(
    'apple.txt', 
    header=None,
    encoding= 'cp1252'
)
df1.rename(
    columns={
        0: 'Apple'
    },
    inplace=True, 
    errors='raise'
)
df1_2 = pd.DataFrame(
    data=df1.Apple.value_counts()
).rename(
    columns={'Apple': 'Frequency'}
).rename_axis(
    'Term'
)
df1_2.to_csv('apple_most_commom_keyword_drilled_down.csv')

# %%
orig_stdout = sys.stdout
f = open(
    'carbon.txt', 'w'
)
sys.stdout = f


for token in doc:
    if 'carbon' in str(token):
        print(token)

sys.stdout = orig_stdout
f.close()

# %%
df2 = pd.read_table(
    'carbon.txt', 
    header=None,
    encoding= 'cp1252'
)
df2.rename(
    columns={
        0: 'Carbon'
    },
    inplace=True, 
    errors='raise'
)
df2_2 = pd.DataFrame(
    data=df2.Carbon.value_counts()
).rename(
    columns={'Carbon': 'Frequency'}
).rename_axis(
    'Term'
)
df2_2.to_csv('apple_second_most_commom_keyword_drilled_down.csv')

# %%
orig_stdout = sys.stdout
f = open(
    'neutral.txt', 'w'
)
sys.stdout = f


for token in doc:
    if 'neutral' in str(token):
        print(token)

sys.stdout = orig_stdout
f.close()

# %%
df3 = pd.read_table(
    'neutral.txt', 
    header=None,
    encoding= 'cp1252'
)
df3.rename(
    columns={
        0: 'Neutral'
    },
    inplace=True, 
    errors='raise'
)
df3_3 = pd.DataFrame(
    data=df3.Neutral.value_counts()
).rename(
    columns={'Neutral': 'Frequency'}
).rename_axis(
    'Term'
)
df3_3.to_csv('apple_third_most_commom_keyword_drilled_down.csv')

# %%
orig_stdout = sys.stdout
f = open(
    'goal.txt', 'w'
)
sys.stdout = f


for token in doc:
    if 'goal' in str(token):
        print(token)

sys.stdout = orig_stdout
f.close()

# %%
df4 = pd.read_table(
    'goal.txt', 
    header=None,
    encoding= 'cp1252'
)
df4.rename(
    columns={
        0: 'Goal'
    },
    inplace=True, 
    errors='raise'
)
df4_4 = pd.DataFrame(
    data=df4.Goal.value_counts()
).rename(
    columns={'Goal': 'Frequency'}
).rename_axis(
    'Term'
)
df4_4.to_csv('apple_fourth_most_commom_keyword_drilled_down.csv')

# %%
orig_stdout = sys.stdout
f = open(
    'gigawatts.txt', 'w'
)
sys.stdout = f


for token in doc:
    if 'gigawatts' in str(token):
        print(token)

sys.stdout = orig_stdout
f.close()

# %%
df5 = pd.read_table(
    'gigawatts.txt', 
    header=None,
    encoding= 'cp1252'
)
df5.rename(
    columns={
        0: 'Gigawatts'
    },
    inplace=True, 
    errors='raise'
)
df5_5= pd.DataFrame(
    data=df5.Gigawatts.value_counts()
).rename(
    columns={'Gigawatts': 'Frequency'}
).rename_axis(
    'Term'
)
df5_5.to_csv('apple_fifth_most_commom_keyword_drilled_down.csv')

# %%
orig_stdout = sys.stdout
f = open(
    'clean.txt', 'w'
)
sys.stdout = f


for token in doc:
    if 'clean' in str(token):
        print(token)

sys.stdout = orig_stdout
f.close()

# %%
df6 = pd.read_table(
    'clean.txt', 
    header=None,
    encoding= 'cp1252'
)
df6.rename(
    columns={
        0: 'Clean'
    },
    inplace=True, 
    errors='raise'
)
df6_6= pd.DataFrame(
    data=df6.Clean.value_counts()
).rename(
    columns={'Clean': 'Frequency'}
).rename_axis(
    'Term'
)
df6_6.to_csv('apple_sixth_most_commom_keyword_drilled_down.csv')

# %%
orig_stdout = sys.stdout
f = open(
    'power.txt', 'w'
)
sys.stdout = f


for token in doc:
    if 'power' in str(token):
        print(token)

sys.stdout = orig_stdout
f.close()

# %%
df7 = pd.read_table(
    'power.txt', 
    header=None,
    encoding= 'cp1252'
)
df7.rename(
    columns={
        0: 'Power'
    },
    inplace=True, 
    errors='raise'
)
df7_7= pd.DataFrame(
    data=df7.Power.value_counts()
).rename(
    columns={'Power': 'Frequency'}
).rename_axis(
    'Term'
)
df7_7.to_csv('apple_seventh_most_commom_keyword_drilled_down.csv')

# %%
orig_stdout = sys.stdout
f = open(
    'supplier.txt', 'w'
)
sys.stdout = f


for token in doc:
    if 'supplier' in str(token):
        print(token)

sys.stdout = orig_stdout
f.close()

# %%
df8 = pd.read_table(
    'supplier.txt', 
    header=None,
    encoding= 'cp1252'
)
df8.rename(
    columns={
        0: 'Supplier'
    },
    inplace=True, 
    errors='raise'
)
df8_8= pd.DataFrame(
    data=df8.Supplier.value_counts()
).rename(
    columns={'Supplier': 'Frequency'}
).rename_axis(
    'Term'
)
df8_8.to_csv('apple_eighth_most_commom_keyword_drilled_down.csv')

# %%
orig_stdout = sys.stdout
f = open(
    'commitments.txt', 'w'
)
sys.stdout = f


for token in doc:
    if 'commitments' in str(token):
        print(token)

sys.stdout = orig_stdout
f.close()

# %%
df9 = pd.read_table(
    'commitments.txt', 
    header=None,
    encoding= 'cp1252'
)
df9.rename(
    columns={
        0: 'Commitments'
    },
    inplace=True, 
    errors='raise'
)
df9_9= pd.DataFrame(
    data=df9.Commitments.value_counts()
).rename(
    columns={'Commitments': 'Frequency'}
).rename_axis(
    'Term'
)
df9_9.to_csv('apple_nineth_most_commom_keyword_drilled_down.csv')

# %%
dff.head()
# Out:
#                                                Title       Date  \
# 0  Apple charges forward to 2030 carbon neutral g... 2021-10-27
# 1          Apple introduces AppleBusiness Essentials 2021-11-10
# 2                   Holiday season kicks off atApple 2021-11-09
# 3               Apple Reports Fourth Quarter Results 2021-10-28
# 4      Apple honors and celebrates American veterans 2021-11-11
#
#                                         Contributors  \
# 0                  Keri Fulton, Apple Media Helpline
# 1  Jessica Reeves, Todd Wilder, Apple Media Helpline
# 2  Gabi Condarco-Quesada, Nick Leahy, Apple Media...
# 3                        Josh Rosenstock, Tejas Gala
# 4  Clare Varellas, Rachel Wolf Tulley, Apple Medi...
#
#                                              Content  \
# 0  October 27, 2021                              ...
# 1  November 10, 2021                             ...
# 2  November 9, 2021                              ...
# ...

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Title          0
# Date           0
# Contributor    0
# Content        0
# link           0
# Role           0
# dtype: int64

# %%
sid.polarity_scores(df.iloc[0]['Content'])
# Out:
# {'neg': 0.013, 'neu': 0.826, 'pos': 0.161, 'compound': 0.9999}

# %%
df.Content[0]
# Out:
# 'PRESS RELEASEOctober 27, 2021                                                    Apple charges forward to 2030 carbon neutral goal, adding 9 gigawatts of clean power and doubling supplier commitments                                                                    Ahead of COP26, Apple launches 10 new initiatives to support communities around the world                                                New clean energy commitments from suppliers help support Apple’s goal to be carbon neutral for its supply chain and products by 2030. Corning Incorporated utilizes clean power from Duke Energy Sustainable Solutions’ Conetoe, North Carolina, solar installation as part of its commitment to power all Apple operations with 100 percent renewable energy.                        CUPERTINO, CALIFORNIAApple today announced it has more than doubled the number of suppliers committed to using 100 percent clean energy over the last year, accelerating progress toward its ambitious 2030 goal to be carb
# ...

# %%
dff['Scores'] = dff['Content'].apply(lambda content: sid.polarity_scores(content))
dff['Compound'] = dff['Scores'].apply(lambda d: d['compound'])
dff['Overall Score'] = dff['Compound'].apply(lambda score: 'POS' if score >=0 else 'NEG')

# %%
dff[dff['Overall Score'] == 'NEG']
# Out:
#                                                   Title       Date  \
# 103   App Store stopped more than $1.5billion in pot... 2021-05-11
# 370      Conserving mangroves, a lifeline for the world 2019-04-22
# 580               iPad Pro artist illustrates NBA stars 2017-04-12
# 635            Apple stores go (RED) for World AIDS Day 2016-12-01
# 1017          Apple Director Jerome B. York Passes Away 2010-03-18
# 1454                     Apple Unveils Final Cut Pro HD 2004-04-18
# 1804         Apple Ups Performance of Power Mac G4 Line 2000-02-16
#
#                                            Contributors  \
# 103   Katie Clark Alsadder, Fred Sainz, Apple Media ...
# 370                   Keri Fulton, Apple Media Helpline
# 580                   Andy Bowman, Apple Media Helpline
# 635                    Nick Leahy, Apple Media Helpline
# 1017                                      Steve Dowling
# 1454                           Cameron Craig, Jerry Hsu
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_df=.9, min_df=.1, stop_words= 'english')

# %%
dtm = cv.fit_transform(dff['Content'])
dtm
# Out:
# <1820x525 sparse matrix of type '<class 'numpy.int64'>'
# 	with 222711 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import LatentDirichletAllocation
LDA = LatentDirichletAllocation(n_components=10)

# %%
LDA.fit(dtm)
# Out:
# LatentDirichletAllocation()

# %%
first_topic = LDA.components_[0]

# %%
first_topic.argsort()
# Out:
# array([395, 200, 162, 418, 170,  14, 404,  13, 451, 227,  97, 345,   0,
#        406, 386,  98, 368, 393,  93, 457, 160, 338, 266,  99, 253,  60,
#        414, 221, 469, 369, 515, 229, 179,  85, 113, 400, 150, 310, 232,
#        390, 265, 307, 120, 435, 483, 289, 411, 233, 274, 228, 252, 324,
#        263, 100, 239,  12, 522, 407, 109, 405, 118,  49, 474, 180, 262,
#        292, 304, 350, 275, 137, 348, 108, 401, 116, 156, 476, 313, 465,
#        291, 318, 365, 103, 132, 105, 236, 195, 215, 198, 212, 452, 111,
#        114, 448, 154, 148,  87, 409, 190, 462, 211,  91, 127, 217, 523,
#        283, 267, 349,  76, 434, 473, 287, 224, 122, 351, 389, 205, 385,
#        330,  75, 399, 142, 423,  61, 341, 320,  17, 486, 182, 206, 223,
#        261,  30, 161, 442, 424, 506, 440, 337,  47,  86, 524, 153, 482,
#        110, 264, 384, 461,  26, 107, 419, 444, 235, 199, 268, 455,  10,
#         38, 135, 299, 290, 331,  21,  67, 441,  53,  78, 342,  20,  52,
# ...

# %%
top_ten = first_topic.argsort()[-10:]

# %%
for index in top_ten:
    print(cv.get_feature_names_out()[index])
# Out:
# features
# core
# inch
# display
# mac
# mini
# performance
# new
# ipad
# pro

# %%
import sys

orig_stdout = sys.stdout
f = open(
    'df.txt', 'w'
)
sys.stdout = f


for index, topic in enumerate(LDA.components_):
    dataframe = pd.DataFrame(columns=[f'THE TOP 15 WORDS FOR TOPIC #{index}'], data=[cv.get_feature_names_out()[index] for index in topic.argsort()[-15:]])
    print(dataframe)

sys.stdout = orig_stdout
f.close()

# %%
dff2 = pd.read_table('df.txt', header=None)
import numpy as np
arr = np.array(dff2)
dataframe = pd.DataFrame(arr.reshape((10, 16))).T
headers = dataframe.iloc[0]
new_df = pd.DataFrame(data=dataframe.values[1:], columns=headers)
new_df
# Out:
# 0      THE TOP 15 WORDS FOR TOPIC #0     THE TOP 15 WORDS FOR TOPIC #1  \
# 0   0                        percent  0                   applications
# 1   1                       powerful  1                     innovative
# 2   2                     generation  2                       hardware
# 3   3                      available  3                           said
# 4   4                         faster  4                      quicktime
# 5   5                       features  5                        product
# 6   6                           core  6                       internet
# 7   7                           inch  7                            new
# 8   8                        display  8                      macintosh
# 9   9                            mac  9                     trademarks
# 10  10                          mini  10                      computer
# 11  11                   performance  11                      software
# ...

# %%
topic_results = LDA.transform(dtm)

# %%
dff['Topic'] = topic_results.argmax(axis=1)

# %%
positive = dff[dff['Overall Score'] == 'POS']
positive.reset_index(drop=True, inplace=True)
negative = dff[dff['Overall Score'] == 'NEG']
negative.reset_index(drop=True, inplace=True)
analytics = dff.groupby('Contributors').count().sort_values(by='Title', ascending=False)
analytics.to_excel('apple_analytics.xlsx')
dff.to_excel('apple_final.xlsx', index=False)
positive.to_excel('apple_positive_articles.xlsx', index=False)
negative.to_excel('apple_negative_articles.xlsx', index=False)
new_df.to_excel('apple_topic.xlsx', index=False)
