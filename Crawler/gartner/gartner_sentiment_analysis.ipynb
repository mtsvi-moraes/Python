# %%
import nltk
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sid = SentimentIntensityAnalyzer()

# %%
df = pd.read_json('gartner_evandro.json')
df.replace(r'\n', '', regex=True, inplace=True)
df.replace(r'\xa0', '', regex=True, inplace=True)
df.replace(r'\r', '', regex=True, inplace=True)
df.head()
# Out:
#                                                Title       Date  \
# 0  The Top 8 Security and Risk Trends We’re Watching 2021-11-15
# 1  Why CISOs Need to Go on the Offensive — And Ho... 2021-11-16
# 2  Data Leaders in Government: These Best Practic... 2021-11-16
# 3  After COP26, Why Supply Chain Leaders Must Ste... 2021-11-17
# 4  I&O Professionals: Develop Emerging Technology... 2021-11-18
#
#      Contributor                                            Content  \
# 0  Kasey Panetta  Explore the latest: Top Strategic Technology T...
# 1  Kasey Panetta  Security and risk leaders are often denied the...
# 2  Jordan Turner  Governments and their agencies must respond to...
# 3  Sarah Hippold  On Sunday, November 14, 2021, the United Natio...
# 4   Meghan Rimol  As organizations begin to recover from the pan...
#
#                                                 Link Role
# 0  https://www.gartner.com/smarterwithgartner/gar...
# 1  https://www.gartner.com/en/articles/why-cisos-...
# 2  https://www.gartner.com/en/articles/data-leade...
# 3  https://www.gartner.com/en/articles/after-cop2...
# 4  https://www.gartner.com/en/articles/i-o-profes...

# %%
df.isnull().sum()
# Out:
# Title          0
# Date           0
# Contributor    0
# Content        0
# Link           0
# Role           0
# dtype: int64

# %%
df.dropna(inplace=True)
df.drop('Role', axis=1, inplace=True)

# %%
sid.polarity_scores(df.iloc[0]['Content'])
# Out:
# {'neg': 0.074, 'neu': 0.727, 'pos': 0.198, 'compound': 0.9989}

# %%
df.Content[0]
# Out:
# 'Explore the latest: Top Strategic Technology Trends 2022As cybersecurity and regulatory compliance become the top two biggest concerns of corporate boards, some are adding cybersecurity experts specifically to scrutinize security and risk issues. This is just one of our top 8 security and risk trends, many of which are driven by recent events such as security breaches and the ongoing COVID-19 pandemic.Download: How to Mature Your Information Security Program“Over the past two years, the typical enterprise has been turned inside out,” says Peter Firstbrook, VP Analyst at Gartner. “As the new normal of hybrid work takes shape, all organizations will need an always-connected defensive posture and clarity on what business risks remote users elevate to remain secure.”This year’s security and risk trends highlight ongoing but not yet widely recognized strategic shifts in the security ecosystem. Each is expected to have broad industry impact and significant potential for disruption.Trend No. 1: Cybersecurity meshThe cybersecurity mesh is a modern conceptual approach to security architecture that enables the distributed enterprise to deploy and extend security where it’s most needed.When COVID-19 accelerated digital business, it also accelerated the trend wherein many digital assets — and individuals — are increasingly located outside of the traditional enterprise infrastructure. In addition, cybersecurity teams are being asked to secure countless forms of digital transformation and other new technologies. This requires security options that are flexible, agile, scalable and composable — those that will enable the organization to move into the future, but in a secure manner.Trend No. 2: Cyber-savvy boardsWith an increase in very public security breaches and increasingly common business disruptions due to ransomware, boards are paying more attention to cybersecurity. They recognize it as a huge risk to enterprises and are forming dedicated committees that focus on cybersecurity matters, often led by a board member with security experience (such as a former chief information security officer [CISO]) or a third-party consultant.This means that CISOs can expect increased scrutiny and expectations, alongside an increase in support and resources. Be prepared to improve communication and expect tougher questions from your board as a result.Trend No. 3: Vendor consolidationThe reality for security today is that security leaders have too many tools. Gartner found in the 2020 CISO Effectiveness Survey that 78% of CISOs have 16 or more tools in their cybersecurity vendor portfolio; 12% have 46 or more. Having too many security vendors results in complex security operations and increased security headcount.Most organizations recognize vendor consolidation as an avenue for more efficient security, with 80% executing or interested in a strategy for this. Large security vendors are responding with better-integrated products. However, consolidation is challenging and often takes years to roll out. Although lower costs are often a perceived driver of this trend, more streamlined operations and reduced risk are often more achievable.Trend No. 4: Identity-first securityHybrid work and the migration to cloud applications have solidified the trend of identity as the perimeter. Identity-first security is not new, but it takes on fresh urgency as attackers begin to target identity and access management capabilities to gain silent persistence.Misused credentials are now the top technique used in breaches. Nation-state-level attackers are targeting active directory and the identity infrastructure with phenomenal success. Identity is a key lateral movement technique across air-gapped networks. Multifactor authentication usage is growing, but it is not a panacea. Identity infrastructure must be properly configured, maintained and monitored with an elevated importance.Trend No. 5: Managing machine identities becoming a critical security capabilityAs digital tra ...

# %%
df['Scores'] = df['Content'].apply(lambda content: sid.polarity_scores(content))
df.head()
# Out:
#                                                Title       Date  \
# 0  The Top 8 Security and Risk Trends We’re Watching 2021-11-15
# 1  Why CISOs Need to Go on the Offensive — And Ho... 2021-11-16
# 2  Data Leaders in Government: These Best Practic... 2021-11-16
# 3  After COP26, Why Supply Chain Leaders Must Ste... 2021-11-17
# 4  I&O Professionals: Develop Emerging Technology... 2021-11-18
#
#      Contributor                                            Content  \
# 0  Kasey Panetta  Explore the latest: Top Strategic Technology T...
# 1  Kasey Panetta  Security and risk leaders are often denied the...
# 2  Jordan Turner  Governments and their agencies must respond to...
# 3  Sarah Hippold  On Sunday, November 14, 2021, the United Natio...
# 4   Meghan Rimol  As organizations begin to recover from the pan...
#
#                                                 Link  \
# 0  https://www.gartner.com/smarterwithgartner/gar...
# 1  https://www.gartner.com/en/articles/why-cisos-...
# 2  https://www.gartner.com/en/articles/data-leade...
# 3  https://www.gartner.com/en/articles/after-cop2...
# 4  https://www.gartner.com/en/articles/i-o-profes...
#
#                                               Scores
# 0  {'neg': 0.074, 'neu': 0.727, 'pos': 0.198, 'co...
# 1  {'neg': 0.084, 'neu': 0.702, 'pos': 0.215, 'co...
# 2  {'neg': 0.03, 'neu': 0.831, 'pos': 0.139, 'com...
# 3  {'neg': 0.028, 'neu': 0.847, 'pos': 0.126, 'co...
# 4  {'neg': 0.045, 'neu': 0.812, 'pos': 0.143, 'co...

# %%
df['Compound'] = df['Scores'].apply(lambda d: d['compound'])
df['Overall Score'] = df['Compound'].apply(lambda score: 'POS' if score >=0 else 'NEG')
df.head()
# Out:
#                                                Title       Date  \
# 0  The Top 8 Security and Risk Trends We’re Watching 2021-11-15
# 1  Why CISOs Need to Go on the Offensive — And Ho... 2021-11-16
# 2  Data Leaders in Government: These Best Practic... 2021-11-16
# 3  After COP26, Why Supply Chain Leaders Must Ste... 2021-11-17
# 4  I&O Professionals: Develop Emerging Technology... 2021-11-18
#
#      Contributor                                            Content  \
# 0  Kasey Panetta  Explore the latest: Top Strategic Technology T...
# 1  Kasey Panetta  Security and risk leaders are often denied the...
# 2  Jordan Turner  Governments and their agencies must respond to...
# 3  Sarah Hippold  On Sunday, November 14, 2021, the United Natio...
# 4   Meghan Rimol  As organizations begin to recover from the pan...
#
#                                                 Link  \
# 0  https://www.gartner.com/smarterwithgartner/gar...
# 1  https://www.gartner.com/en/articles/why-cisos-...
# 2  https://www.gartner.com/en/articles/data-leade...
# 3  https://www.gartner.com/en/articles/after-cop2...
# 4  https://www.gartner.com/en/articles/i-o-profes...
#
#                                               Scores  Compound Overall Score
# 0  {'neg': 0.074, 'neu': 0.727, 'pos': 0.198, 'co...    0.9989           POS
# 1  {'neg': 0.084, 'neu': 0.702, 'pos': 0.215, 'co...    0.9985           POS
# 2  {'neg': 0.03, 'neu': 0.831, 'pos': 0.139, 'com...    0.9962           POS
# 3  {'neg': 0.028, 'neu': 0.847, 'pos': 0.126, 'co...    0.9975           POS
# 4  {'neg': 0.045, 'neu': 0.812, 'pos': 0.143, 'co...    0.9964           POS

# %%
df[df['Overall Score'] == 'NEG']
# Out:
#                                                   Title       Date  \
# 18    Technology GMs: Adjust Your Product Strategies... 2020-05-08
# 79             Protect Against the Petya Malware Attack 2017-06-28
# 98    IT Projects Need Less Complexity, Not More Gov... 2015-07-17
# 121   Think About Digital Ethics Within Continually ... 2015-04-01
# 137      The Fad, Function, and Fashion of Smartwatches 2015-02-18
# ...                                                 ...        ...
# 1566  How to Set Practical Time Frames to Remedy Sec... 2021-06-23
# 1570       How Can Governments Scale Up Cloud Adoption? 2021-06-30
# 1582  4 HR Talent Strategies for the Postpandemic La... 2021-06-08
# 1621      6 Ways Cloud Migration Costs Go Off the Rails 2021-07-07
# 1632  Global HR Leaders Reveal Where Their Companies... 2021-08-06
#
#             Contributor                                            Content  \
# 18         Meghan Rimol  COVID-19 has impacted every aspect of society,...
# 79        Kasey Panetta  Editor's Note: This article was updated on Jun...
# 98          Susan Moore  Despite more than 50 years of history and coun...
# 121    Frank Buytendijk  The emerging discipline of digital ethics will...
# 137          Tom McCall  Your grandfather's Swiss watch sits on the dre...
# ...                 ...                                                ...
# 1566        Susan Moore  It might be possible to patch every Windows sy...
# 1570  Laurence Goasduff  Cloud computing is now more than a decade old ...
# 1582       Teresa Zuech  Explore the latest: Top 5 HR Trends and Priori...
# 1621       Meghan Rimol  More than 70% of companies have now migrated a...
# 1632        Brian Kropp  Nearly 70% of HR leaders report that their emp...
#
#                                                    Link  \
# 18    https://www.gartner.com/smarterwithgartner/tec...
# 79    https://www.gartner.com/smarterwithgartner/pro...
# 98    https://www.gartner.com/smarterwithgartner/it-...
# 121   https://www.gartner.com/smarterwithgartner/thi...
# 137   https://www.gartner.com/smarterwithgartner/the...
# ...                                                 ...
# 1566  https://www.gartner.com/smarterwithgartner/how...
# 1570  https://www.gartner.com/smarterwithgartner/how...
# 1582  https://www.gartner.com/smarterwithgartner/4-h...
# 1621  https://www.gartner.com/smarterwithgartner/6-w...
# 1632  https://www.gartner.com/smarterwithgartner/glo...
#
#                                                  Scores  Compound  \
# 18    {'neg': 0.073, 'neu': 0.858, 'pos': 0.069, 'co...   -0.8363
# 79    {'neg': 0.165, 'neu': 0.782, 'pos': 0.053, 'co...   -0.9977
# 98    {'neg': 0.099, 'neu': 0.806, 'pos': 0.095, 'co...   -0.2543
# 121   {'neg': 0.125, 'neu': 0.763, 'pos': 0.112, 'co...   -0.8796
# 137   {'neg': 0.06, 'neu': 0.895, 'pos': 0.046, 'com...   -0.6407
# ...                                                 ...       ...
# 1566  {'neg': 0.161, 'neu': 0.725, 'pos': 0.114, 'co...   -0.9758
# 1570  {'neg': 0.059, 'neu': 0.88, 'pos': 0.061, 'com...   -0.1045
# 1582  {'neg': 0.136, 'neu': 0.749, 'pos': 0.115, 'co...   -0.2500
# 1621  {'neg': 0.077, 'neu': 0.864, 'pos': 0.059, 'co...   -0.8592
# 1632  {'neg': 0.065, 'neu': 0.883, 'pos': 0.053, 'co...   -0.8534
#
#      Overall Score
# 18             NEG
# 79             NEG
# 98             NEG
# 121            NEG
# 137            NEG
# ...            ...
# 1566           NEG
# 1570           NEG
# 1582           NEG
# 1621           NEG
# 1632           NEG
#
# [90 rows x 8 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_df=.9, min_df=.1, stop_words= 'english')
dtm = cv.fit_transform(df['Content'])

# %%
dtm
# Out:
# <1640x398 sparse matrix of type '<class 'numpy.int64'>'
# 	with 123627 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import LatentDirichletAllocation
LDA = LatentDirichletAllocation(n_components=10)
LDA.fit(dtm)
# Out:
# LatentDirichletAllocation()

# %%
first_topic = LDA.components_[0]
first_topic.argsort()
# Out:
# array([315,  18, 318, 216, 374,  48,  79, 333, 176,  58, 353,  27, 257,
#         22, 162, 137, 349, 175, 205,  54, 192, 389, 115,  34, 366, 356,
#        393, 152, 116,  16, 373, 382, 226, 381, 163,  30,  97, 313, 203,
#        284, 395, 184, 264, 182, 255, 355, 258, 360,  67, 275,  74,  55,
#        154, 387,  94, 149,  82,  56,  99,  64, 100, 320, 292,  90, 304,
#        121, 254,  23,  10, 223, 195, 263, 291, 370, 122, 200, 230, 357,
#        278, 117, 177, 388, 178, 245,  24, 372, 376,   1, 268,  17, 202,
#         19, 144,  41, 277, 186, 151,  15, 394, 296, 153, 265, 365, 324,
#        148,  84, 136,   3,   2, 103, 229, 297, 328, 332,   7, 196, 174,
#        156, 312, 286, 199, 207, 338,  76, 385,  69, 269,  93, 161,  43,
#          5, 283, 107,  53,  47, 119, 214, 334, 140, 309, 391,  81, 326,
#        231, 118, 208,  77, 158, 170, 134, 190, 272, 173,  12, 132,  49,
#        371,  68, 375, 271,  60, 306,  70,  75, 128, 295, 369, 143,   4,
#        181, 307, 305, 108,  39, 352, 135, 212,  83,   8, 380, 247, 276,
#        102, 125, 294,   6,  65, 113, 232, 139,  63, 310, 378, 219, 213,
#        290, 126, 166,  28, 233, 172, 330,  31, 252, 240, 228,  46,  20,
#        105, 227,  59, 127, 354, 289,  85, 311,  35, 131, 225, 111, 259,
#         11, 169, 285, 351,  61,  95, 104, 364,   0, 359,  88, 282, 209,
#         51, 266, 308,  89, 129, 377, 383,  32, 288, 204,  92, 301,  40,
#        329, 197, 397, 159, 147, 224, 331, 298, 179, 238, 337, 109, 253,
#        193, 300, 235,  21,  14,  29, 183, 220, 363, 368, 101, 386,  96,
#        198, 317, 251, 241, 244,  38,  57,   9, 114, 133, 157, 319, 171,
#        221, 348, 160, 335,  71, 110, 217, 345, 314, 343, 106, 287, 341,
#        167, 323, 390, 215, 336,  80, 206,  62, 361, 185,  87,  98, 168,
#        281, 146, 191, 339, 347, 299, 210,  50, 396, 327,  52, 138, 250,
#         26, 392, 302, 142, 236, 340, 270, 112,  37, 358, 262, 130,  45,
#        237, 120, 267, 150,  91, 123, 239, 246, 325,  44, 124, 242, 321,
#         66, 249, 379, 293, 145, 303,  86,  33, 243,  13, 274, 188, 248,
#        211, 350,  36, 316, 164,  78, 218, 342, 187,  25, 234, 155, 165,
#        141, 322, 194, 256, 189, 260, 367, 362, 273, 261, 346, 280, 180,
#        279, 222, 201, 384, 344,  73,  72,  42], dtype=int64)

# %%
top_ten = first_topic.argsort()[-10:]
for index in top_ten:
    print(cv.get_feature_names_out()[index])
# Out:
# projects
# initiatives
# project
# management
# leaders
# value
# strategic
# costs
# cost
# business

# %%
import sys

orig_stdout = sys.stdout
f = open(
    'df.txt', 'w'
)
sys.stdout = f


for index, topic in enumerate(LDA.components_):
    dataframe = pd.DataFrame(columns=[f'THE TOP 15 WORDS FOR TOPIC #{index}'], data=[cv.get_feature_names_out()[index] for index in topic.argsort()[-15:]])
    print(dataframe)

sys.stdout = orig_stdout
f.close()

# %%
df2 = pd.read_table('df.txt', header=None)
import numpy as np
arr = np.array(df2)
dataframe = pd.DataFrame(arr.reshape((10, 16))).T
headers = dataframe.iloc[0]
new_df = pd.DataFrame(data=dataframe.values[1:], columns=headers)
new_df
# Out:
# 0      THE TOP 15 WORDS FOR TOPIC #0     THE TOP 15 WORDS FOR TOPIC #1  \
# 0   0                           time  0                          value
# 1   1                           term  1                       managers
# 2   2                        process  2                           make
# 3   3                       planning  3                           high
# 4   4                       strategy  4                        process
# 5   5                       projects  5                            new
# 6   6                    initiatives  6                         growth
# 7   7                        project  7                        leaders
# 8   8                     management  8                    information
# 9   9                        leaders  9                      marketing
# 10  10                         value  10                        market
# 11  11                     strategic  11                     customers
# 12  12                         costs  12                      customer
# 13  13                          cost  13                       product
# 14  14                      business  14                         sales
#
# 0      THE TOP 15 WORDS FOR TOPIC #2     THE TOP 15 WORDS FOR TOPIC #3  \
# 0   0                        quality  0                       pandemic
# 1   1                       insights  1                   organization
# 2   2                         making  2                           need
# 3   3                     governance  3                             19
# 4   4                      decisions  4                          covid
# 5   5                   organization  5                      workforce
# 6   6                          value  6                       managers
# 7   7                        leaders  7                  organizations
# 8   8                            use  8                        leaders
# 9   9                  organizations  9                         skills
# 10  10                      decision  10                        talent
# 11  11                   information  11                      employee
# 12  12                      business  12                            hr
# 13  13                     analytics  13                          work
# 14  14                          data  14                     employees
#
# 0      THE TOP 15 WORDS FOR TOPIC #4     THE TOP 15 WORDS FOR TOPIC #5  \
# 0   0                          value  0                       learning
# 1   1                     innovation  1                   intelligence
# 2   2                           said  2                           data
# 3   3                     enterprise  3                        devices
# 4   4                           need  4                          human
# 5   5                  organizations  5                         things
# 6   6                   organization  6                       business
# 7   7                         change  7                            iot
# 8   8                     technology  8                          smart
# 9   9                            cio  9                            new
# 10  10                transformation  10                           use
# 11  11                           new  11                       digital
# 12  12                          cios  12                  technologies
# 13  13                      business  13                    technology
# 14  14                       digital  14                            ai
#
# 0      THE TOP 15 WORDS FOR TOPIC #6     THE TOP 15 WORDS FOR TOPIC #7  \
# 0   0                        company  0                       research
# 1   1                           need  1                           says
# 2   2                     leadership  2                            new
# 3   3                            new  3                        company
# 4   4                       strategy  4                         demand
# 5   5                         people  5                        support
# 6   6                           make  6                      companies
# 7   7                           work  7                  organizations
# 8   8                           time  8                        leaders
# 9   9                          teams  9                     experience
# 10  10                        change  10                     customers
# 11  11                  organization  11                       service
# 12  12                       culture  12                         chain
# 13  13                       leaders  13                      customer
# 14  14                          team  14                        supply
#
# 0      THE TOP 15 WORDS FOR TOPIC #8     THE TOP 15 WORDS FOR TOPIC #9
# 0   0                        systems  0                     technology
# 1   1                     management  1                         design
# 2   2                       business  2                           says
# 3   3                            use  3                     innovation
# 4   4                         access  4                       emerging
# 5   5                       software  5                      potential
# 6   6                   applications  6                         impact
# 7   7                           data  7                   organization
# 8   8                        service  8                  organizations
# 9   9                 infrastructure  9                        leaders
# 10  10                 organizations  10                      security
# 11  11                   application  11                    management
# 12  12                      services  12                         risks
# 13  13                      security  13                      business
# 14  14                         cloud  14                          risk

# %%
topic_results = LDA.transform(dtm)
topic_results[0].argmax()
# Out:
# 8

# %%
df['Topic'] = topic_results.argmax(axis=1)

# %%
positive = df[df['Overall Score'] == 'POS']
positive.reset_index(drop=True, inplace=True)
negative = df[df['Overall Score'] == 'NEG']
negative.reset_index(drop=True, inplace=True)
analytics = df.groupby('Contributor').count().sort_values(by='Title', ascending=False)
analytics.to_excel('gartner_alytics.xlsx')
df.to_excel('gartner_final.xlsx', index=False)
positive.to_excel('gartner_positive_articles.xlsx', index=False)
negative.to_excel('gartner_negative_articles.xlsx', index=False)
new_df.to_excel('gartner_topic.xlsx', index=False)
