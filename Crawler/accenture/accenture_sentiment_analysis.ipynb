# %%
import nltk
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sid = SentimentIntensityAnalyzer()

# %%
df = pd.read_json('accenture_evandro.json')
df.replace(r'\n', '', regex=True, inplace=True)
df.replace(r'\xa0', '', regex=True, inplace=True)
df.replace(r'\r', '', regex=True, inplace=True)
df.replace(r'<h4>', '', inplace=True)
df.replace(r's:,', '', inplace=True)
df.replace(r'\n', '', inplace=True)
df.replace(r'\t', '', inplace=True)

df.head()
# Out:
#                                                Title       Date  \
# 0       Accenture Completes Acquisition of BRIDGEi2i 2021-11-18
# 1  Accenture and Envision Partner to Help Clients... 2021-11-11
# 2  Accenture Acquires T.A. Cook, Strengthening As... 2021-11-15
# 3  Accenture Acquires Founders Intelligence to He... 2021-11-16
# 4  Accenture and Organon Team Up to Drive Digital... 2021-11-17
#
#                                          Contributor  \
# 0  [s:, Katy Rosati, Subhashini Pattabhiraman, Co...
# 1         [s:, Junaidah Dahlan, Minjie Zha, Ash Lim]
# 2  [s:, Jens R. Derksen, Yvonne Bernerth, Copyrig...
# 3                [:, Natalie de Freitas, Copyright ]
# 4                   [:, Marchell Gillis, Copyright ]
#
#                                              Content  \
# 0  November 18, 2021Accenture Completes Acquisiti...
# 1  November 11, 2021Accenture and Envision Partne...
# 2  November 15, 2021Accenture Acquires T.A. Cook,...
# 3  November 16, 2021Accenture Acquires Founders I...
# 4  November 17, 2021Accenture and Organon Team Up...
#
#                                                 Link Role
# 0  https://newsroom.accenture.com/news/accenture-...
# 1  https://newsroom.accenture.com/news/accenture-...
# 2  https://newsroom.accenture.com/news/accenture-...
# 3  https://newsroom.accenture.com/news/accenture-...
# 4  https://newsroom.accenture.com/news/accenture-...

# %%
df.isnull().sum()
# Out:
# Title          0
# Date           4
# Contributor    0
# Content        0
# Link           0
# Role           0
# dtype: int64

# %%
df.dropna(inplace=True)
df.drop('Role', axis=1, inplace=True)

# %%
sid.polarity_scores(df.iloc[0]['Content'])
# Out:
# {'neg': 0.087, 'neu': 0.795, 'pos': 0.119, 'compound': 0.9909}

# %%
df.Content[0]
# Out:
# 'November 18, 2021Accenture Completes Acquisition of BRIDGEi2iBENGALURU, India; Nov. 18, 2021– Accenture (NYSE: ACN) has completed its acquisition of BRIDGEi2i, an artificial intelligence (AI) and analytics firm headquartered in Bengaluru, India. The financial terms of the transaction were not disclosed.The acquisition, announced last month, strengthens Accenture’s global capabilities in data science, machine learning and AI-powered insights, and adds more than 800 deeply skilled professionals to Accenture’s Applied Intelligence practice.Founded in 2011 and with a presence in India, the US and Australia, BRIDGEi2i specializes in data-driven digital transformation for companies across industries and global markets by combining data engineering, advanced analytics, proprietary AI accelerators and consulting services.About AccentureAccenture is a global professional services company with leading capabilities in digital, cloud and security. Combining unmatched experience and specialized skills across more than 40 industries, we offer Strategy and Consulting, Interactive, Technology and Operations services — all powered by the world’s largest network of Advanced Technology and Intelligent Operations centers. Our 624,000 people deliver on the promise of technology and human ingenuity every day, serving clients in more than 120 countries. We embrace the power of change to create value and shared success for our clients, people, shareholders, partners and communities. Visit us at www.accenture.com.Applied Intelligence is Accenture’s approach to scaling AI for clients by embedding AI-powered data, analytics and automation capabilities into business workflows, accelerating time to value with a powerful global alliance, innovation and delivery network that can deploy and scale AI within any market and industry. To learn more, visit www.accenture.com/appliedintelligence.Forward-Looking StatementsExcept for the historical information and discussions contained herein, statements in this news release may constitute forward-looking statements within the meaning of the Private Securities Litigation Reform Act of 1995. Words such as “may,” “will,” “should,” “likely,” “anticipates,” “expects,” “intends,” “plans,” “projects,” “believes,” “estimates,” “positioned,” “outlook” and similar expressions are used to identify these forward-looking statements. These statements involve a number of risks, uncertainties and other factors that could cause actual results to differ materially from those expressed or implied. These risks include, without limitation, risks that: the transaction might not achieve the anticipated benefits for Accenture; the COVID-19 pandemic has impacted Accenture’s business and operations, and the extent to which it will continue to do so and its impact on the company’s future financial results are uncertain; Accenture’s results of operations have been, and may in the future be, adversely affected by volatile, negative or uncertain economic and political conditions and the effects of these conditions on the company’s clients’ businesses and levels of business activity; Accenture’s business depends on generating and maintaining ongoing, profitable client demand for the company’s services and solutions including through the adaptation and expansion of its services and solutions in response to ongoing changes in technology and offerings, and a significant reduction in such demand or an inability to respond to the evolving technological environment could materially affect the company’s results of operations; if Accenture is unable to keep its supply of skills and resources in balance with client demand around the world and attract and retain professionals with strong leadership skills, the company’s business, the utilization rate of the company’s professionals and the company’s results of operations may be materially adversely affected; Accenture faces legal, reputational and financial risks from any failure to protect client and/or c ...

# %%
df['Scores'] = df['Content'].apply(lambda content: sid.polarity_scores(content))
df
# Out:
#                                                   Title       Date  \
# 0          Accenture Completes Acquisition of BRIDGEi2i 2021-11-18
# 1     Accenture and Envision Partner to Help Clients... 2021-11-11
# 2     Accenture Acquires T.A. Cook, Strengthening As... 2021-11-15
# 3     Accenture Acquires Founders Intelligence to He... 2021-11-16
# 4     Accenture and Organon Team Up to Drive Digital... 2021-11-17
# ...                                                 ...        ...
# 4881  Accenture Makes Strategic Investment in Beamer... 2021-06-17
# 4882  Accenture and Avanade Named to the Leaders Cat... 2021-06-17
# 4883  Accenture Announces Intent to Acquire Strategy... 2021-06-18
# 4884  Accenture Federal Services Wins $112 million T... 2021-06-18
# 4885  Accenture to Host Conference Call Tomorrow, Ju... 2021-06-23
#
#                                             Contributor  \
# 0     [s:, Katy Rosati, Subhashini Pattabhiraman, Co...
# 1            [s:, Junaidah Dahlan, Minjie Zha, Ash Lim]
# 2     [s:, Jens R. Derksen, Yvonne Bernerth, Copyrig...
# 3                   [:, Natalie de Freitas, Copyright ]
# 4                      [:, Marchell Gillis, Copyright ]
# ...                                                 ...
# 4881   [s:, Hannah Unkefer, Tourang Nazari, Copyright ]
# 4882               [s:, Hannah Unkefer, Matthew Tucker]
# 4883           [s:, Velislava Le Fevre, Bonnie OLIVIER]
# 4884                                [:, Donna Savarese]
# 4885                                  [:, Stacey Jones]
#
#                                                 Content  \
# 0     November 18, 2021Accenture Completes Acquisiti...
# 1     November 11, 2021Accenture and Envision Partne...
# 2     November 15, 2021Accenture Acquires T.A. Cook,...
# 3     November 16, 2021Accenture Acquires Founders I...
# 4     November 17, 2021Accenture and Organon Team Up...
# ...                                                 ...
# 4881  June 17, 2021Accenture Makes Strategic Investm...
# 4882  June 17, 2021Accenture and Avanade Named to th...
# 4883  June 18, 2021Accenture Announces Intent to Acq...
# 4884  June 18, 2021Accenture Federal Services Wins $...
# 4885  June 23, 2021Accenture to Host Conference Call...
#
#                                                    Link  \
# 0     https://newsroom.accenture.com/news/accenture-...
# 1     https://newsroom.accenture.com/news/accenture-...
# 2     https://newsroom.accenture.com/news/accenture-...
# 3     https://newsroom.accenture.com/news/accenture-...
# 4     https://newsroom.accenture.com/news/accenture-...
# ...                                                 ...
# 4881  https://newsroom.accenture.com/news/accenture-...
# 4882  https://newsroom.accenture.com/news/accenture-...
# 4883  https://newsroom.accenture.com/news/accenture-...
# 4884  https://newsroom.accenture.com/news/accenture-...
# 4885  https://newsroom.accenture.com/news/accenture-...
#
#                                                  Scores
# 0     {'neg': 0.087, 'neu': 0.795, 'pos': 0.119, 'co...
# 1     {'neg': 0.007, 'neu': 0.826, 'pos': 0.167, 'co...
# 2     {'neg': 0.071, 'neu': 0.783, 'pos': 0.146, 'co...
# 3     {'neg': 0.078, 'neu': 0.763, 'pos': 0.16, 'com...
# 4     {'neg': 0.017, 'neu': 0.843, 'pos': 0.14, 'com...
# ...                                                 ...
# 4881  {'neg': 0.008, 'neu': 0.849, 'pos': 0.142, 'co...
# 4882  {'neg': 0.01, 'neu': 0.838, 'pos': 0.152, 'com...
# 4883  {'neg': 0.071, 'neu': 0.792, 'pos': 0.138, 'co...
# 4884  {'neg': 0.025, 'neu': 0.819, 'pos': 0.156, 'co...
# 4885  {'neg': 0.005, 'neu': 0.887, 'pos': 0.108, 'co...
#
# [4882 rows x 6 columns]

# %%
df['Compound'] = df['Scores'].apply(lambda d: d['compound'])
df['Overall Score'] = df['Compound'].apply(lambda score: 'POS' if score >=0 else 'NEG')
df.drop('Contributor', axis =1, inplace = True)

# %%
df[df['Overall Score'] == 'NEG']
# Out:
#                                                   Title       Date  \
# 243   More than Half of U.S. Consumers Say Poor Serv... 2010-09-22
# 351   Accenture and Employees to Contribute Up to $4... 2001-09-16
# 401                 Accenture Response to Media Inquiry 2002-01-22
# 476   One-Fourth of Americans Say It’s Acceptable to... 2003-02-12
# 565   Americans Believe Insurance Fraud Occurs Becau... 2004-05-25
# 993   Accenture Study Finds Widespread Customer Serv... 2007-05-21
# 1163  Untapped Potential: Half of Female Executives ... 2009-03-02
# 4003  Low Consumer “Literacy” of Healthcare System E... 2018-09-12
# 4653  Accenture and MIT Team to Create a Supply Chai... 2020-10-26
#
#                                                 Content  \
# 243   More than Half of U.S. Consumers Say Poor Serv...
# 351   Accenture and Employees to Contribute Up to $4...
# 401   Accenture Response to Media Inquiry NEW YORK, ...
# 476   One-Fourth of Americans Say It’s Acceptable to...
# 565   Americans Believe Insurance Fraud Occurs Becau...
# 993   Accenture Study Finds Widespread Customer Serv...
# 1163  Untapped Potential:  Half of Female Executives...
# 4003  September 12, 2018Low Consumer “Literacy” of H...
# 4653  October 26, 2020Accenture and MIT Team to Crea...
#
#                                                    Link  \
# 243   https://newsroom.accenture.com/news/more-than-...
# 351   https://newsroom.accenture.com/news/accenture-...
# 401   https://newsroom.accenture.com/news/accenture-...
# 476   https://newsroom.accenture.com/news/one-fourth...
# 565   https://newsroom.accenture.com/news/americans-...
# 993   https://newsroom.accenture.com/news/accenture-...
# 1163  https://newsroom.accenture.com/news/untapped-p...
# 4003  https://newsroom.accenture.com/news/low-consum...
# 4653  https://newsroom.accenture.com/news/accenture-...
#
#                                                  Scores  Compound  \
# 243   {'neg': 0.073, 'neu': 0.852, 'pos': 0.075, 'co...   -0.8815
# 351   {'neg': 0.09, 'neu': 0.82, 'pos': 0.09, 'compo...   -0.6808
# 401   {'neg': 0.043, 'neu': 0.912, 'pos': 0.045, 'co...   -0.1658
# 476   {'neg': 0.109, 'neu': 0.784, 'pos': 0.107, 'co...   -0.9156
# 565   {'neg': 0.124, 'neu': 0.796, 'pos': 0.081, 'co...   -0.9860
# 993   {'neg': 0.084, 'neu': 0.843, 'pos': 0.073, 'co...   -0.8141
# 1163  {'neg': 0.215, 'neu': 0.785, 'pos': 0.0, 'comp...   -0.4770
# 4003  {'neg': 0.073, 'neu': 0.885, 'pos': 0.043, 'co...   -0.9581
# 4653  {'neg': 0.112, 'neu': 0.815, 'pos': 0.073, 'co...   -0.9884
#
#      Overall Score
# 243            NEG
# 351            NEG
# 401            NEG
# 476            NEG
# 565            NEG
# 993            NEG
# 1163           NEG
# 4003           NEG
# 4653           NEG

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_df=.9, min_df=.1, stop_words= 'english')
dtm = cv.fit_transform(df['Content'])

# %%
dtm
# Out:
# <4882x603 sparse matrix of type '<class 'numpy.int64'>'
# 	with 667712 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import LatentDirichletAllocation
LDA = LatentDirichletAllocation(n_components=10)
LDA.fit(dtm)
# Out:
# LatentDirichletAllocation()

# %%
first_topic = LDA.components_[0]
first_topic.argsort()
# Out:
# array([478,  77, 490, 550, 565,  12, 351, 192, 549,  70, 415, 546, 338,
#        112, 545, 489, 485,  85, 414, 553, 487, 531, 567, 347, 526, 443,
#        528, 327, 541, 146, 455, 437, 340, 123, 562, 343, 166, 428, 309,
#        556, 573, 274, 344, 314, 426, 175, 137, 413, 336, 276, 356, 104,
#         72,  45, 452, 358, 176, 507, 424, 278,  60, 444, 448, 537, 234,
#        191, 453, 197, 279, 353, 312, 538, 307, 253,  48, 469, 467, 297,
#        525, 505, 552, 548, 236, 126, 508, 100, 449, 292, 566, 384, 200,
#        209, 180, 377, 458, 254, 184, 504, 441,  63, 593,  61, 362, 256,
#        308, 447, 136, 165, 502, 195, 370, 355, 589, 238, 281, 581, 585,
#        491, 459, 326, 248,  52, 440, 201, 222, 232,  66, 501, 156, 522,
#        293, 535,  99, 121, 148, 369, 203, 239, 584, 407, 319, 480, 208,
#        500, 439, 221, 520, 571, 436, 451, 559, 568, 303, 378, 476, 132,
#        310,  58, 158, 368, 359, 382, 547,  80, 305, 115,  76, 518, 179,
#        235, 140, 139, 399, 332, 113, 542, 215,  53, 372, 506, 120, 107,
#        261,  54, 595, 395, 516, 198, 196, 220, 127, 280, 212, 511, 230,
#        266, 320, 481, 265, 217, 432, 403, 105, 247, 108, 431, 315, 530,
#        569, 342, 316, 233, 177, 383, 214, 271, 463, 172, 385, 572, 284,
#        205, 223,  43,  59, 178, 264, 334, 330,  93, 114, 188, 341, 376,
#        328, 410, 213, 430, 160, 109, 153, 361, 202, 349, 519, 131, 429,
#        532, 142, 576, 591, 345, 141, 145, 262, 246, 594, 555, 514,  49,
#        434, 116, 245, 331, 325, 204,  89, 333, 171,  44, 143,  67, 189,
#        364, 224,  82, 337, 374, 435, 272, 357, 438, 596, 597, 598, 182,
#        322, 590, 174, 433,  96, 155, 421,  95,  81, 162, 346, 186, 283,
#        391, 483, 492, 354, 446, 509, 409,  51, 551, 259, 298, 119, 495,
#        579, 527, 393, 168, 499, 219,  39, 411, 218, 267, 169, 462, 306,
#        524, 185, 199, 225, 401, 313, 587, 477, 494, 117, 405,  65, 255,
#        601, 529, 302, 173, 128, 242, 299,  98, 400, 228, 321, 460, 574,
#        360, 534, 570, 339, 250, 419, 147, 588, 329, 402, 473, 366, 512,
#        543, 210, 291, 257, 484, 275, 159, 260, 193, 379, 457, 580, 269,
#         88,  71, 474, 539, 304, 578, 408,  68, 190, 380, 560,  62, 163,
#        135, 241, 381, 206, 183, 396, 154, 187, 124, 450,  57,  92,  41,
#         55, 472,  73, 465,  40, 470, 111, 417, 427, 243, 521, 461, 352,
#        387, 288, 582, 454, 296,  20, 503, 151,  21,  22, 161, 425, 301,
#        412, 317, 216, 445,  34, 181,  64, 471, 335, 290, 244,  56, 164,
#         33, 285,  37, 586, 110, 392, 397, 270, 371, 583,  91,  87, 420,
#         38, 287, 442,  78, 194, 286,  15, 510,  32, 564, 486, 277, 231,
#        577, 557, 375,  75, 138, 558, 167, 144, 561,  16, 544, 282, 323,
#        456,  36, 129,  19, 130, 523, 300, 513,  69,  14,  90, 468, 479,
#        125, 249, 170, 498, 133, 496, 398,   4, 251,  97, 229, 150,  17,
#        295,  18,  46, 540,  42, 227, 488,  35, 103, 226, 263,   1, 517,
#        294, 118, 475, 258,  10, 152,  79,  13, 122, 311, 101,   6,  24,
#         47, 318,   9, 418,  11, 273, 363, 211, 365,  27,  23, 466, 592,
#         25,   8,  84, 533, 252,  83, 157, 390,  28, 388,   5, 554, 348,
#        389, 482,   3, 416, 394,  26,  50, 106, 423, 268, 350,  30, 324,
#        404, 134, 602, 563,  29,   0, 149,   7, 536,   2,  86, 575, 289,
#         74, 406, 207, 493, 422, 515,  31, 599, 237, 367, 102,  94, 497,
#        464, 373, 600, 386, 240], dtype=int64)

# %%
top_ten = first_topic.argsort()[-10:]
for index in top_ten:
    print(cv.get_feature_names_out()[index])
# Out:
# financial
# marketing
# canada
# billion
# revenues
# quarter
# million
# year
# net
# fiscal

# %%
import sys

orig_stdout = sys.stdout
f = open(
    'df.txt', 'w'
)
sys.stdout = f


for index, topic in enumerate(LDA.components_):
    dataframe = pd.DataFrame(columns=[f'THE TOP 15 WORDS FOR TOPIC #{index}'], data=[cv.get_feature_names_out()[index] for index in topic.argsort()[-15:]])
    print(dataframe)

sys.stdout = orig_stdout
f.close()

# %%
df2 = pd.read_table('df.txt', header=None)
import numpy as np
arr = np.array(df2)
dataframe = pd.DataFrame(arr.reshape((10, 16))).T
headers = dataframe.iloc[0]
new_df = pd.DataFrame(data=dataframe.values[1:], columns=headers)
new_df
# Out:
# 0      THE TOP 15 WORDS FOR TOPIC #0     THE TOP 15 WORDS FOR TOPIC #1  \
# 0   0                        results  0                    governments
# 1   1                        percent  1                     experience
# 2   2                          share  2                     successful
# 3   3                             31  3                            aug
# 4   4                            www  4                           home
# 5   5                      financial  5                             31
# 6   6                      marketing  6                   capabilities
# 7   7                         canada  7                        support
# 8   8                        billion  8                      companies
# 9   9                       revenues  9                       research
# 10  10                       quarter  10                   performance
# 11  11                       million  11                          high
# 12  12                          year  12                   outsourcing
# 13  13                           net  13                          year
# 14  14                        fiscal  14                    management
#
# 0      THE TOP 15 WORDS FOR TOPIC #2     THE TOP 15 WORDS FOR TOPIC #3  \
# 0   0                        ability  0                     businesses
# 1   1                         demand  1                      expertise
# 2   2                     businesses  2                       industry
# 3   3                         client  3                        process
# 4   4                        looking  4                          state
# 5   5                        forward  5                      resources
# 6   6                        digital  6                        finance
# 7   7                      financial  7                    outsourcing
# 8   8                      solutions  8                        service
# 9   9                        changes  9                    performance
# 10  10                    materially  10                   information
# 11  11                         risks  11                           new
# 12  12                    statements  12                    management
# 13  13                       results  13                        public
# 14  14                    operations  14                    government
#
# 0      THE TOP 15 WORDS FOR TOPIC #4     THE TOP 15 WORDS FOR TOPIC #5  \
# 0   0                        systems  0                       strategy
# 1   1                          group  1                  organizations
# 2   2                           cost  2                   technologies
# 3   3                     materially  3                       industry
# 4   4                      solutions  4                          study
# 5   5                       exchange  5                       customer
# 6   6                     management  6                           data
# 7   7                        factors  7                         growth
# 8   8                     securities  8                       research
# 9   9                          risks  9                         report
# 10  10                    operations  10                    executives
# 11  11                       forward  11                       percent
# 12  12                       looking  12                       digital
# 13  13                       results  13                           new
# 14  14                    statements  14                     companies
#
# 0      THE TOP 15 WORDS FOR TOPIC #6     THE TOP 15 WORDS FOR TOPIC #7  \
# 0   0                          visit  0                       research
# 1   1                        largest  1                      providers
# 2   2                      solutions  2                     operations
# 3   3                        network  3                         leader
# 4   4                     operations  4                      solutions
# 5   5                         skills  5                         energy
# 6   6                       strategy  6                         market
# 7   7                         create  7                         report
# 8   8                        leading  8                       industry
# 9   9                     experience  9                        service
# 10  10                       improve  10                  capabilities
# 11  11                         works  11                          data
# 12  12                           new  12                     analytics
# 13  13                       digital  13                       digital
# 14  14                    innovation  14                         cloud
#
# 0      THE TOP 15 WORDS FOR TOPIC #8     THE TOP 15 WORDS FOR TOPIC #9
# 0   0                      companies  0                          based
# 1   1                       customer  1                        product
# 2   2                     experience  2                       products
# 3   3                         mobile  3                      companies
# 4   4                       research  4                       industry
# 5   5                        service  5                        service
# 6   6                       consumer  6                     management
# 7   7                           half  7                       platform
# 8   8                            use  8                       solution
# 9   9                           year  9                      customers
# 10  10                        online  10                           new
# 11  11                     consumers  11                     insurance
# 12  12                   respondents  12                      customer
# 13  13                        survey  13                     solutions
# 14  14                       percent  14                      software

# %%
topic_results = LDA.transform(dtm)
topic_results[0].argmax()
# Out:
# 2

# %%
df['Topic'] = topic_results.argmax(axis=1)

# %%
positive = df[df['Overall Score'] == 'POS']
positive.reset_index(drop=True, inplace=True)
negative = df[df['Overall Score'] == 'NEG']
negative.reset_index(drop=True, inplace=True)
analytics = df.groupby('Date').count().sort_values(by='Title', ascending=False)
analytics.to_excel('accenture_analytics.xlsx')
df.to_excel('accenture_final.xlsx', index=False)
positive.to_excel('accenture_positive_articles.xlsx', index=False)
negative.to_excel('accenture_negative_articles.xlsx', index=False)
new_df.to_excel('acccenture_topic.xlsx', index=False)

# %%
positive
# Out:
#                                                   Title       Date  \
# 0          Accenture Completes Acquisition of BRIDGEi2i 2021-11-18
# 1     Accenture and Envision Partner to Help Clients... 2021-11-11
# 2     Accenture Acquires T.A. Cook, Strengthening As... 2021-11-15
# 3     Accenture Acquires Founders Intelligence to He... 2021-11-16
# 4     Accenture and Organon Team Up to Drive Digital... 2021-11-17
# ...                                                 ...        ...
# 4868  Accenture Makes Strategic Investment in Beamer... 2021-06-17
# 4869  Accenture and Avanade Named to the Leaders Cat... 2021-06-17
# 4870  Accenture Announces Intent to Acquire Strategy... 2021-06-18
# 4871  Accenture Federal Services Wins $112 million T... 2021-06-18
# 4872  Accenture to Host Conference Call Tomorrow, Ju... 2021-06-23
#
#                                                 Content  \
# 0     November 18, 2021Accenture Completes Acquisiti...
# 1     November 11, 2021Accenture and Envision Partne...
# 2     November 15, 2021Accenture Acquires T.A. Cook,...
# 3     November 16, 2021Accenture Acquires Founders I...
# 4     November 17, 2021Accenture and Organon Team Up...
# ...                                                 ...
# 4868  June 17, 2021Accenture Makes Strategic Investm...
# 4869  June 17, 2021Accenture and Avanade Named to th...
# 4870  June 18, 2021Accenture Announces Intent to Acq...
# 4871  June 18, 2021Accenture Federal Services Wins $...
# 4872  June 23, 2021Accenture to Host Conference Call...
#
#                                                    Link  \
# 0     https://newsroom.accenture.com/news/accenture-...
# 1     https://newsroom.accenture.com/news/accenture-...
# 2     https://newsroom.accenture.com/news/accenture-...
# 3     https://newsroom.accenture.com/news/accenture-...
# 4     https://newsroom.accenture.com/news/accenture-...
# ...                                                 ...
# 4868  https://newsroom.accenture.com/news/accenture-...
# 4869  https://newsroom.accenture.com/news/accenture-...
# 4870  https://newsroom.accenture.com/news/accenture-...
# 4871  https://newsroom.accenture.com/news/accenture-...
# 4872  https://newsroom.accenture.com/news/accenture-...
#
#                                                  Scores  Compound  \
# 0     {'neg': 0.087, 'neu': 0.795, 'pos': 0.119, 'co...    0.9909
# 1     {'neg': 0.007, 'neu': 0.826, 'pos': 0.167, 'co...    0.9967
# 2     {'neg': 0.071, 'neu': 0.783, 'pos': 0.146, 'co...    0.9988
# 3     {'neg': 0.078, 'neu': 0.763, 'pos': 0.16, 'com...    0.9987
# 4     {'neg': 0.017, 'neu': 0.843, 'pos': 0.14, 'com...    0.9974
# ...                                                 ...       ...
# 4868  {'neg': 0.008, 'neu': 0.849, 'pos': 0.142, 'co...    0.9959
# 4869  {'neg': 0.01, 'neu': 0.838, 'pos': 0.152, 'com...    0.9987
# 4870  {'neg': 0.071, 'neu': 0.792, 'pos': 0.138, 'co...    0.9984
# 4871  {'neg': 0.025, 'neu': 0.819, 'pos': 0.156, 'co...    0.9953
# 4872  {'neg': 0.005, 'neu': 0.887, 'pos': 0.108, 'co...    0.9781
#
#      Overall Score  Topic
# 0              POS      2
# 1              POS      6
# 2              POS      2
# 3              POS      2
# 4              POS      7
# ...            ...    ...
# 4868           POS      6
# 4869           POS      7
# 4870           POS      2
# 4871           POS      6
# 4872           POS      0
#
# [4873 rows x 8 columns]
