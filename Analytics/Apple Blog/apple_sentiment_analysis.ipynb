# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
df = pd.read_json('apple2.json')
df.replace(r'\n', '', regex=True, inplace=True)
df.replace(r'\xa0', '', regex=True, inplace=True)
df.replace(r'\r', '', regex=True, inplace=True)
df.replace(r'<h4>', '', inplace=True)
df.replace(r's:,', '', inplace=True)
df.replace(r'\n', '', inplace=True)
df.replace(r'\t', '', inplace=True)
df.head()
# Out:
#                                                Title       Date  \
# 0  Apple charges forward to 2030 carbon neutral g... 2021-10-27
# 1          Apple introduces AppleBusiness Essentials 2021-11-10
# 2                   Holiday season kicks off atApple 2021-11-09
# 3               Apple Reports Fourth Quarter Results 2021-10-28
# 4      Apple honors and celebrates American veterans 2021-11-11
#
#                                          Contributor  \
# 0                [Keri Fulton, Apple Media Helpline]
# 1  [Jessica Reeves, Todd Wilder, Apple Media Help...
# 2  [Gabi Condarco-Quesada, Nick Leahy, Apple Medi...
# 3                      [Josh Rosenstock, Tejas Gala]
# 4  [Clare Varellas, Rachel Wolf Tulley, Apple Med...
#
#                                              Content  \
# 0  PRESS RELEASEOctober 27, 2021                 ...
# 1  PRESS RELEASENovember 10, 2021                ...
# 2  UPDATENovember 9, 2021                        ...
# 3  PRESS RELEASEOctober 28, 2021                 ...
# 4  UPDATENovember 11, 2021                       ...
#
#                                                 link           Role
# 0  https://www.apple.com/newsroom/2021/10/apple-c...  Press Contact
# 1  https://www.apple.com/newsroom/2021/11/apple-i...  Press Contact
# 2  https://www.apple.com/newsroom/2021/11/holiday...  Press Contact
# 3  https://www.apple.com/newsroom/2021/10/apple-r...  Press Contact
# 4  https://www.apple.com/newsroom/2021/11/apple-h...  Press Contact

# %%
df.isnull().sum()
# Out:
# Title          0
# Date           0
# Contributor    0
# Content        0
# link           0
# Role           0
# dtype: int64

# %%
sid = SentimentIntensityAnalyzer()

# %%
sid.polarity_scores(df.iloc[0]['Content'])
# Out:
# {'neg': 0.013, 'neu': 0.826, 'pos': 0.161, 'compound': 0.9999}

# %%
df['Scores'] = df['Content'].apply(lambda content: sid.polarity_scores(content))
df
# Out:
#                                                   Title       Date  \
# 0     Apple charges forward to 2030 carbon neutral g... 2021-10-27
# 1             Apple introduces AppleBusiness Essentials 2021-11-10
# 2                      Holiday season kicks off atApple 2021-11-09
# 3                  Apple Reports Fourth Quarter Results 2021-10-28
# 4         Apple honors and celebrates American veterans 2021-11-11
# ...                                                 ...        ...
# 1815              Apple Teams with Kanisa for e-Service 2000-04-05
# 1816  Apple’s QuickTime 4 Downloads Top 32 Million a... 2000-04-05
# 1817  Apple Acquires DVD Authoring Technology, Produ... 2000-04-10
# 1818  Apple Unveils Mac OS X and Internet Strategy a... 2000-01-05
# 1819  Apple's QuickTime TV Network Scores Super Bowl... 2000-01-24
#
#                                             Contributor  \
# 0                   [Keri Fulton, Apple Media Helpline]
# 1     [Jessica Reeves, Todd Wilder, Apple Media Help...
# 2     [Gabi Condarco-Quesada, Nick Leahy, Apple Medi...
# 3                         [Josh Rosenstock, Tejas Gala]
# 4     [Clare Varellas, Rachel Wolf Tulley, Apple Med...
# ...                                                 ...
# 1815          [Alec Rosen, Keith Goldberg, Kanisa Inc.]
# 1816      [Vanessa Rios, Bob Berger, Edelman Worldwide]
# 1817                                   [Matt Hutchison]
# 1818                   [Matt Hutchison, Rhona Hamilton]
# 1819    [Matt Hutchison, Bob Berger, Edelman Worldwide]
#
#                                                 Content  \
# 0     PRESS RELEASEOctober 27, 2021                 ...
# 1     PRESS RELEASENovember 10, 2021                ...
# 2     UPDATENovember 9, 2021                        ...
# 3     PRESS RELEASEOctober 28, 2021                 ...
# 4     UPDATENovember 11, 2021                       ...
# ...                                                 ...
# 1815  PRESS RELEASEApril 5, 2000                    ...
# 1816  PRESS RELEASEApril 5, 2000                    ...
# 1817  PRESS RELEASEApril 10, 2000                   ...
# 1818  PRESS RELEASEJanuary 5, 2000                  ...
# 1819  PRESS RELEASEJanuary 24, 2000                 ...
#
#                                                    link           Role  \
# 0     https://www.apple.com/newsroom/2021/10/apple-c...  Press Contact
# 1     https://www.apple.com/newsroom/2021/11/apple-i...  Press Contact
# 2     https://www.apple.com/newsroom/2021/11/holiday...  Press Contact
# 3     https://www.apple.com/newsroom/2021/10/apple-r...  Press Contact
# 4     https://www.apple.com/newsroom/2021/11/apple-h...  Press Contact
# ...                                                 ...            ...
# 1815  https://www.apple.com/newsroom/2000/04/05Apple...  Press Contact
# 1816  https://www.apple.com/newsroom/2000/04/05Apple...  Press Contact
# 1817  https://www.apple.com/newsroom/2000/04/10Apple...  Press Contact
# 1818  https://www.apple.com/newsroom/2000/01/05Apple...  Press Contact
# 1819  https://www.apple.com/newsroom/2000/01/24Apple...  Press Contact
#
#                                                  Scores
# 0     {'neg': 0.013, 'neu': 0.826, 'pos': 0.161, 'co...
# 1     {'neg': 0.013, 'neu': 0.845, 'pos': 0.141, 'co...
# 2     {'neg': 0.003, 'neu': 0.79, 'pos': 0.207, 'com...
# 3     {'neg': 0.066, 'neu': 0.848, 'pos': 0.086, 'co...
# 4     {'neg': 0.047, 'neu': 0.816, 'pos': 0.137, 'co...
# ...                                                 ...
# 1815  {'neg': 0.008, 'neu': 0.828, 'pos': 0.163, 'co...
# 1816  {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compou...
# 1817  {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'comp...
# 1818  {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'comp...
# 1819  {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'comp...
#
# [1820 rows x 7 columns]

# %%
df['Compound'] = df['Scores'].apply(lambda d: d['compound'])
df['Overall Score'] = df['Compound'].apply(lambda score: 'POS' if score >=0 else 'NEG')
df.head()
# Out:
#                                                Title       Date  \
# 0  Apple charges forward to 2030 carbon neutral g... 2021-10-27
# 1          Apple introduces AppleBusiness Essentials 2021-11-10
# 2                   Holiday season kicks off atApple 2021-11-09
# 3               Apple Reports Fourth Quarter Results 2021-10-28
# 4      Apple honors and celebrates American veterans 2021-11-11
#
#                                          Contributor  \
# 0                [Keri Fulton, Apple Media Helpline]
# 1  [Jessica Reeves, Todd Wilder, Apple Media Help...
# 2  [Gabi Condarco-Quesada, Nick Leahy, Apple Medi...
# 3                      [Josh Rosenstock, Tejas Gala]
# 4  [Clare Varellas, Rachel Wolf Tulley, Apple Med...
#
#                                              Content  \
# 0  PRESS RELEASEOctober 27, 2021                 ...
# 1  PRESS RELEASENovember 10, 2021                ...
# 2  UPDATENovember 9, 2021                        ...
# 3  PRESS RELEASEOctober 28, 2021                 ...
# 4  UPDATENovember 11, 2021                       ...
#
#                                                 link           Role  \
# 0  https://www.apple.com/newsroom/2021/10/apple-c...  Press Contact
# 1  https://www.apple.com/newsroom/2021/11/apple-i...  Press Contact
# 2  https://www.apple.com/newsroom/2021/11/holiday...  Press Contact
# 3  https://www.apple.com/newsroom/2021/10/apple-r...  Press Contact
# 4  https://www.apple.com/newsroom/2021/11/apple-h...  Press Contact
#
#                                               Scores  Compound Overall Score
# 0  {'neg': 0.013, 'neu': 0.826, 'pos': 0.161, 'co...    0.9999           POS
# 1  {'neg': 0.013, 'neu': 0.845, 'pos': 0.141, 'co...    0.9996           POS
# 2  {'neg': 0.003, 'neu': 0.79, 'pos': 0.207, 'com...    0.9999           POS
# 3  {'neg': 0.066, 'neu': 0.848, 'pos': 0.086, 'co...    0.9752           POS
# 4  {'neg': 0.047, 'neu': 0.816, 'pos': 0.137, 'co...    0.9994           POS

# %%
df[df['Overall Score'] == 'NEG']
# Out:
#                                                   Title       Date  \
# 103   App Store stopped more than $1.5billion in pot... 2021-05-11
# 370      Conserving mangroves, a lifeline for the world 2019-04-22
# 580               iPad Pro artist illustrates NBA stars 2017-04-12
# 635            Apple stores go (RED) for World AIDS Day 2016-12-01
# 1017          Apple Director Jerome B. York Passes Away 2010-03-18
# 1454                     Apple Unveils Final Cut Pro HD 2004-04-18
# 1804         Apple Ups Performance of Power Mac G4 Line 2000-02-16
#
#                                             Contributor  \
# 103   [Katie Clark Alsadder, Fred Sainz, Apple Media...
# 370                 [Keri Fulton, Apple Media Helpline]
# 580                 [Andy Bowman, Apple Media Helpline]
# 635                  [Nick Leahy, Apple Media Helpline]
# 1017                                    [Steve Dowling]
# 1454                         [Cameron Craig, Jerry Hsu]
# 1804    [Matt Hutchison, Bob Berger, Edelman Worldwide]
#
#                                                 Content  \
# 103   UPDATEMay 11, 2021                            ...
# 370   FEATUREApril 22, 2019                         ...
# 580   UPDATEApril 12, 2017                          ...
# 635   PHOTOSDecember 1, 2016                        ...
# 1017  PRESS RELEASEMarch 18, 2010                   ...
# 1454  PRESS RELEASEApril 18, 2004                   ...
# 1804  PRESS RELEASEFebruary 16, 2000                ...
#
#                                                    link           Role  \
# 103   https://www.apple.com/newsroom/2021/05/app-sto...  Press Contact
# 370   https://www.apple.com/newsroom/2019/04/conserv...  Press Contact
# 580   https://www.apple.com/newsroom/2017/04/ipad-pr...  Press Contact
# 635   https://www.apple.com/newsroom/2016/12/apple-s...  Press Contact
# 1017  https://www.apple.com/newsroom/2010/03/18Apple...  Press Contact
# 1454  https://www.apple.com/newsroom/2004/04/18Apple...  Press Contact
# 1804  https://www.apple.com/newsroom/2000/02/16Apple...  Press Contact
#
#                                                  Scores  Compound  \
# 103   {'neg': 0.165, 'neu': 0.716, 'pos': 0.119, 'co...   -0.9980
# 370   {'neg': 0.04, 'neu': 0.929, 'pos': 0.031, 'com...   -0.9660
# 580   {'neg': 0.072, 'neu': 0.854, 'pos': 0.074, 'co...   -0.5423
# 635   {'neg': 0.046, 'neu': 0.921, 'pos': 0.033, 'co...   -0.0516
# 1017  {'neg': 0.052, 'neu': 0.91, 'pos': 0.038, 'com...   -0.4391
# 1454  {'neg': 0.086, 'neu': 0.854, 'pos': 0.06, 'com...   -0.8555
# 1804  {'neg': 0.048, 'neu': 0.906, 'pos': 0.046, 'co...   -0.2728
#
#      Overall Score
# 103            NEG
# 370            NEG
# 580            NEG
# 635            NEG
# 1017           NEG
# 1454           NEG
# 1804           NEG

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_df=.9, min_df=.1, stop_words= 'english')
dtm = cv.fit_transform(df['Content'])

# %%
dtm
# Out:
# <1820x525 sparse matrix of type '<class 'numpy.int64'>'
# 	with 222493 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import LatentDirichletAllocation
LDA = LatentDirichletAllocation(n_components=10)
LDA.fit(dtm)
# Out:
# LatentDirichletAllocation()

# %%
first_topic = LDA.components_[0]
first_topic.argsort()
# Out:
# array([161, 199, 393, 402, 451,  14, 404,  97, 149,  13,  98, 169, 226,
#        147, 418,  93, 391, 366, 178, 159,  60,   0, 367, 398, 227, 148,
#        363, 265, 331, 252,  76, 310, 407, 306, 336, 457, 251, 388, 109,
#        113, 405,  85,  99, 264,  90, 515, 274, 480, 384,  49, 108, 469,
#        463, 474, 220, 442, 118, 312, 232, 303,  53, 235, 383, 309, 349,
#        482, 231, 105, 343, 205,  87, 116, 506,  91, 238, 288,  86, 473,
#        282, 448, 114, 424, 476, 266, 414, 269, 434, 189, 123, 228, 160,
#        339, 181, 120, 209, 212, 297, 524, 261,  78, 136, 298, 323, 411,
#        210,  72, 122, 485, 194, 103, 100,  18, 234,  75, 155, 273,  61,
#         38, 135, 172, 483, 347,  39, 107, 102, 223, 387, 508, 364, 121,
#        173, 267, 329, 430,  70, 262,  15, 319, 270, 304, 352, 168, 462,
#        403, 101, 152,  22, 141, 416,  29, 179,  50, 222, 279, 275, 230,
#        245, 444, 382, 132, 208,  19, 249,  12, 255, 217, 365, 263, 437,
#        193, 214, 332, 111, 289, 299, 514, 348, 204, 153, 461, 291, 499,
#        287, 419, 351, 211, 243, 162, 326, 422, 522, 392,  67, 134, 246,
#        330,  20, 370, 468, 203, 440, 216, 385, 104,  21,  34, 342, 435,
#        406, 196, 470, 373, 493,  43, 126, 292, 427, 321, 453, 340, 318,
#        397,  10, 198,  47, 170, 163, 218, 184,  65, 501,  17, 443, 381,
#        127, 180, 487, 202, 420, 423, 350, 197, 489, 325, 421, 484,  33,
#         73, 145, 518,  80, 523, 441, 490, 455, 415, 357, 110, 215, 182,
#        248, 346, 242,  58,  96, 175, 293, 432, 396, 517, 369, 395, 439,
#        425, 260, 286, 511,  28, 125, 519, 436, 417, 128, 115, 280, 361,
#        341, 281, 399, 277, 250, 467, 158, 295, 449, 296, 494, 327, 497,
#        488,  26, 507, 276, 294,  35,  30, 505, 186, 165, 510, 112, 305,
#         44, 428,  56,  11, 500,  23, 512, 308, 164, 290, 221,  25, 412,
#        237, 445, 144, 301, 171, 307, 131, 378,  77,  16, 225, 504, 458,
#          1, 106, 317, 335, 311, 247, 124, 151, 358, 167, 452, 154, 446,
#        386, 454, 408, 177, 137, 368,  62, 475,  31, 176, 166, 362,  54,
#        314,   3, 278, 390, 509, 521, 233, 478, 324, 322,  42, 300, 272,
#        239, 285,  84,   8, 354,  52, 253,  94, 174, 491, 185, 344, 157,
#         45, 117, 471,   9, 140, 409,  83,  88, 302, 371, 394, 380,  89,
#         32, 256,  71,  82, 429, 374, 206, 320, 334, 496, 219,  40, 244,
#        200, 146,  46,  37,  74,  69, 129,   7, 229, 187, 472, 138, 447,
#        486, 438, 190, 492, 356, 503, 241,  24, 254, 359, 207, 400, 258,
#        337, 401,  79, 133,  48, 224, 389, 268, 477, 213, 495, 520, 465,
#         36,  27,  57, 333,   2,  51, 271, 376, 379,  64,  92, 192, 119,
#        450, 139, 479, 410, 426, 413, 513, 284, 498, 375,  55, 466,  95,
#          4, 433,  68, 464, 338, 516, 431, 195, 345, 150, 456, 143, 188,
#        460, 183, 360, 502,  66, 372, 240, 353, 236, 481,   6,  41, 355,
#        142, 316, 283,  63, 201, 315, 459,  81, 191, 156,   5, 130, 313,
#        259,  59, 377, 328, 257], dtype=int64)

# %%
top_ten = first_topic.argsort()[-10:]
for index in top_ten:
    print(cv.get_feature_names_out()[index])
# Out:
# features
# display
# 12
# customers
# mini
# iphone
# available
# pro
# new
# ipad

# %%
import sys

orig_stdout = sys.stdout
f = open(
    'apple_topic.txt', 'w'
)
sys.stdout = f


for index, topic in enumerate(LDA.components_):
    dataframe = pd.DataFrame(columns=[f'THE TOP 15 WORDS FOR TOPIC #{index}'], data=[cv.get_feature_names_out()[index] for index in topic.argsort()[-15:]])
    print(dataframe)

sys.stdout = orig_stdout
f.close()

# %%
df2 = pd.read_table('apple_topic.txt', header=None)
import numpy as np
arr = np.array(df2)
dataframe = pd.DataFrame(arr.reshape((10, 16))).T
headers = dataframe.iloc[0]
new_df = pd.DataFrame(data=dataframe.values[1:], columns=headers)
new_df
# Out:
# 0      THE TOP 15 WORDS FOR TOPIC #0     THE TOP 15 WORDS FOR TOPIC #1  \
# 0   0                        battery  0                     revolution
# 1   1                     generation  1                     trademarks
# 2   2                          model  2                          today
# 3   3                          store  3                            new
# 4   4                         camera  4                       personal
# 5   5                       features  5                      available
# 6   6                        display  6                       computer
# 7   7                             12  7                         online
# 8   8                      customers  8                        digital
# 9   9                           mini  9                          songs
# 10  10                        iphone  10                           mac
# 11  11                     available  11                         store
# 12  12                           pro  12                          ipod
# 13  13                           new  13                        itunes
# 14  14                          ipad  14                         music
#
# 0      THE TOP 15 WORDS FOR TOPIC #2     THE TOP 15 WORDS FOR TOPIC #3  \
# 0   0                          world  0                         faster
# 1   1                          phone  1                      processor
# 2   2                      available  2                          built
# 3   3                          press  3                         memory
# 4   4                  revolutionary  4                          power
# 5   5                         itunes  5                       graphics
# 6   6                     trademarks  6                          video
# 7   7                           ipad  7                          drive
# 8   8                          touch  8                        display
# 9   9                            app  9                    performance
# 10  10                           mac  10                          core
# 11  11                            os  11                          inch
# 12  12                        mobile  12                           mac
# 13  13                         store  13                           new
# 14  14                        iphone  14                           pro
#
# 0      THE TOP 15 WORDS FOR TOPIC #4     THE TOP 15 WORDS FOR TOPIC #5  \
# 0   0                       services  0                          steve
# 1   1                         better  1                            www
# 2   2                          users  2                        product
# 3   3                      including  3                            mac
# 4   4                       software  4                        company
# 5   5                     technology  5                             00
# 6   6                           apps  6                       internet
# 7   7                        devices  7                     conference
# 8   8                          macos  8                       software
# 9   9                           data  9                          press
# 10  10                         world  10                     macintosh
# 11  11                           pay  11                    trademarks
# 12  12                           new  12                      computer
# 13  13                           ios  13                      personal
# 14  14                        iphone  14                     quicktime
#
# 0      THE TOP 15 WORDS FOR TOPIC #6     THE TOP 15 WORDS FOR TOPIC #7  \
# 0   0                        million  0                       features
# 1   1                             10  1                          video
# 2   2                          sales  2                     trademarks
# 3   3                          share  3                          power
# 4   4                      including  4                       computer
# 5   5                        product  5                       personal
# 6   6                       business  6                      available
# 7   7                       services  7                      macintosh
# 8   8                           year  8                   applications
# 9   9                        percent  9                          users
# 10  10                       billion  10                      software
# 11  11                       results  11                           pro
# 12  12                      products  12                           new
# 13  13                       quarter  13                            os
# 14  14                       company  14                           mac
#
# 0      THE TOP 15 WORDS FOR TOPIC #8     THE TOP 15 WORDS FOR TOPIC #9
# 0   0                         photos  0                        support
# 1   1                     experience  1                      including
# 2   2                           news  2                         health
# 3   3                          watch  3                         people
# 4   4                          music  4                       students
# 5   5                            ios  5                         series
# 6   6                         iphone  6                      customers
# 7   7                       features  7                          today
# 8   8                           ipad  8                           year
# 9   9                      available  9                           help
# 10  10                          apps  10                         world
# 11  11                            tv  11                         store
# 12  12                           app  12                           new
# 13  13                         users  13                           app
# 14  14                           new  14                         watch

# %%
topic_results = LDA.transform(dtm)
topic_results[0].argmax()
# Out:
# 9

# %%
df['Topic'] = topic_results.argmax(axis=1)
df.head()
# Out:
#                                                Title       Date  \
# 0  Apple charges forward to 2030 carbon neutral g... 2021-10-27
# 1          Apple introduces AppleBusiness Essentials 2021-11-10
# 2                   Holiday season kicks off atApple 2021-11-09
# 3               Apple Reports Fourth Quarter Results 2021-10-28
# 4      Apple honors and celebrates American veterans 2021-11-11
#
#                                          Contributor  \
# 0                [Keri Fulton, Apple Media Helpline]
# 1  [Jessica Reeves, Todd Wilder, Apple Media Help...
# 2  [Gabi Condarco-Quesada, Nick Leahy, Apple Medi...
# 3                      [Josh Rosenstock, Tejas Gala]
# 4  [Clare Varellas, Rachel Wolf Tulley, Apple Med...
#
#                                              Content  \
# 0  PRESS RELEASEOctober 27, 2021                 ...
# 1  PRESS RELEASENovember 10, 2021                ...
# 2  UPDATENovember 9, 2021                        ...
# 3  PRESS RELEASEOctober 28, 2021                 ...
# 4  UPDATENovember 11, 2021                       ...
#
#                                                 link           Role  \
# 0  https://www.apple.com/newsroom/2021/10/apple-c...  Press Contact
# 1  https://www.apple.com/newsroom/2021/11/apple-i...  Press Contact
# 2  https://www.apple.com/newsroom/2021/11/holiday...  Press Contact
# 3  https://www.apple.com/newsroom/2021/10/apple-r...  Press Contact
# 4  https://www.apple.com/newsroom/2021/11/apple-h...  Press Contact
#
#                                               Scores  Compound Overall Score  \
# 0  {'neg': 0.013, 'neu': 0.826, 'pos': 0.161, 'co...    0.9999           POS
# 1  {'neg': 0.013, 'neu': 0.845, 'pos': 0.141, 'co...    0.9996           POS
# 2  {'neg': 0.003, 'neu': 0.79, 'pos': 0.207, 'com...    0.9999           POS
# 3  {'neg': 0.066, 'neu': 0.848, 'pos': 0.086, 'co...    0.9752           POS
# 4  {'neg': 0.047, 'neu': 0.816, 'pos': 0.137, 'co...    0.9994           POS
#
#    Topic
# 0      9
# 1      4
# 2      9
# 3      6
# 4      9

# %%
df.to_excel('apple_final.xlsx', index=False)
new_df.to_excel('apple_topic.xlsx', index=False)
