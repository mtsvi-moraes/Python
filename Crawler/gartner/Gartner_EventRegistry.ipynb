# %%
import pandas as pd
import json
import re

# %%
er = pd.read_json('event_registry.json')
er
# Out:
#                                                        articles
# page                                                          1
# pages                                                        40
# results       [{'uri': '6770363346', 'lang': 'eng', 'isDupli...
# totalResults                                               7908

# %%
nested = pd.DataFrame(er.articles.values.tolist()).loc[2, 0]
frame = pd.DataFrame.from_records(nested)
event_registry = frame.drop(labels=['lang', 'isDuplicate', 'time', 'dateTime', 'dateTimePub', 'sim', 
                            'body', 'source', 'authors','image', 'eventUri', 'wgt'], axis=1)
event_registry_slice = event_registry.drop(['uri', 'dataType', 'url', 'sentiment', 'relevance'], axis=1)
event_registry_slice.columns = event_registry_slice.columns.str.replace('date', 'Date')
event_registry_slice.columns = event_registry_slice.columns.str.replace('title', 'Article')
event_registry_slice.Date = pd.to_datetime(event_registry_slice.Date)
event_registry_slice.drop('Date', inplace=True, axis=1)
event_registry_slice
# Out:
#                                                Article
# 0    Start A Business, Get An MSc - The University ...
# 1    Empire BlueCross CEO, president: Innovation st...
# 2    Report: 76% of manufacturers plan to adopt pri...
# 3    AI Weekly: AI model training costs on the rise...
# 4                        Growing the U.S. AI Workforce
# ..                                                 ...
# 195  Indian entrepreneur addresses employers confer...
# 196  Minneapolis Schools' 'Gaggle' Software On Kids...
# 197  Sensyne Health and OMNY Health Sign Teaming Ag...
# 198  Show 250 and 12th Year Anniversary Week for Ne...
# 199  International ZIM Network: SmartMed - Regenera...
#
# [200 rows x 1 columns]

# %%
gartner = pd.read_csv('gartner_no_date.csv')[:200]
gartner
# Out:
#                                                  Title  \
# 0    3 Supply Chain Strategies to Drive Purpose-Dri...
# 1    How to Deliver Relevant Content Across the Tec...
# 2    6 Key Takeaways from the Gartner Board of Dire...
# 3     IT Budgets Are Growing. Here's Where the Mone...
# 4    The Top 8 Cybersecurity Predictions for 2021-2022
# ..                                                 ...
# 195  Redesign Recruiting Strategies to Hire Quality...
# 196  5 Trends From the Gartner Hype Cycle for Suppl...
# 197  3 Sustainable Retailing Practices for Supply C...
# 198  Future of Sales 2025: Data-Driven B2B Selling ...
# 199  Build Organizational Resilience for Today and ...
#
#                                                   Link
# 0    www.gartner.com/en/articles/3-supply-chain-str...
# 1    www.gartner.com/en/articles/how-to-deliver-rel...
# 2    www.gartner.com/en/articles/6-key-takeaways-fr...
# 3    www.gartner.com/en/articles/it-budgets-are-gro...
# 4    www.gartner.com/en/articles/the-top-8-cybersec...
# ..                                                 ...
# 195  www.gartner.com/smarterwithgartner/redesign-re...
# 196  www.gartner.com/smarterwithgartner/5-trends-fr...
# 197  www.gartner.com/smarterwithgartner/3-sustainab...
# 198  www.gartner.com/smarterwithgartner/future-of-s...
# 199  www.gartner.com/smarterwithgartner/build-organ...
#
# [200 rows x 2 columns]

# %%
df = pd.concat([event_registry_slice, gartner], axis=1)
df
# Out:
#                                                Article  \
# 0    Start A Business, Get An MSc - The University ...
# 1    Empire BlueCross CEO, president: Innovation st...
# 2    Report: 76% of manufacturers plan to adopt pri...
# 3    AI Weekly: AI model training costs on the rise...
# 4                        Growing the U.S. AI Workforce
# ..                                                 ...
# 195  Indian entrepreneur addresses employers confer...
# 196  Minneapolis Schools' 'Gaggle' Software On Kids...
# 197  Sensyne Health and OMNY Health Sign Teaming Ag...
# 198  Show 250 and 12th Year Anniversary Week for Ne...
# 199  International ZIM Network: SmartMed - Regenera...
#
#                                                  Title  \
# 0    3 Supply Chain Strategies to Drive Purpose-Dri...
# 1    How to Deliver Relevant Content Across the Tec...
# 2    6 Key Takeaways from the Gartner Board of Dire...
# 3     IT Budgets Are Growing. Here's Where the Mone...
# 4    The Top 8 Cybersecurity Predictions for 2021-2022
# ..                                                 ...
# 195  Redesign Recruiting Strategies to Hire Quality...
# 196  5 Trends From the Gartner Hype Cycle for Suppl...
# 197  3 Sustainable Retailing Practices for Supply C...
# 198  Future of Sales 2025: Data-Driven B2B Selling ...
# 199  Build Organizational Resilience for Today and ...
#
#                                                   Link
# 0    www.gartner.com/en/articles/3-supply-chain-str...
# 1    www.gartner.com/en/articles/how-to-deliver-rel...
# 2    www.gartner.com/en/articles/6-key-takeaways-fr...
# 3    www.gartner.com/en/articles/it-budgets-are-gro...
# 4    www.gartner.com/en/articles/the-top-8-cybersec...
# ..                                                 ...
# 195  www.gartner.com/smarterwithgartner/redesign-re...
# 196  www.gartner.com/smarterwithgartner/5-trends-fr...
# 197  www.gartner.com/smarterwithgartner/3-sustainab...
# 198  www.gartner.com/smarterwithgartner/future-of-s...
# 199  www.gartner.com/smarterwithgartner/build-organ...
#
# [200 rows x 3 columns]
